# %%
import re

#import parse
import pdfplumber
import pandas as pd
from collections import namedtuple
file = 'C:\\Users\\APELI\\Desktop\\PDF_EXTRACT\\PDF\\TEST\\MARTHA A OMACI MANIFESTE.pdf'

lines = []
total_check = 0

with pdfplumber.open(file) as pdf:
    pages = pdf.pages
    for page in pdf.pages:
        text = page.extract_text()
        for line in text.split('\n'):
            print(line)
# Out:
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 1 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0001)------------------------------------------------------------------------------------------------------------------
# HLCUANR221214610 SWB ONE 40' X 8' X 9'6" REEFER CON SLAC
# HL-REF: 30005413 2,085 CARTONS 27,395.000 KGM GROSS
# (001) 756 CARTONS
# SHIPPER: FROZEN PORK NECKBONES 50.000 MTQ GROSS
# NORWEST FOODS INTERNATIONAL LTD. NET WEIGHT: 12852.00 KG
# 3 HAIG COURT, HAIG ROAD, GROSS WEIGHT: 13384.00 KG
# KNUTSFORD, CHESHIRE,
# WA16 8XZ, 875 CARTONS
# UNITED KINGDOM FROZEN PORK FRONT FEET
# +44 (0) 1565 759 000 NET WEIGHT: 8750.00 KG
# GROSS WEIGHT: 9282.00 KG
# CONSIGNEE:
# YASK-SERVICES 454 CARTONS
# 13 BP 193 FROZEN PORK RIBLETS
# ABIDJAN 13 NET WEIGHT: 4540.00 KG
# COTE D 'IVOIRE GROSS WEIGHT: 4729.00 KG
# NOTIFY PARTY 1: TOTAL NET WEIGHT:
# YASK-SERVICES 26142.00 KG
# 13 BP 193
# ABIDJAN 13 BSC NO. #CIIMP-207550
# COTE D 'IVOIRE HS-CODE : 02 06 49
# PLACE OF RECEIPT (START):
# BEANR; ANTWERP UACU 4787442 (45R1)
# SEAL NO 1: BS0989161
# PLACE OF DELIVERY (END): TARE WEIGHT: 4,585 KGM
# CIABJ; ABIDJAN
# FCL/FCL
# BILL TOTALS 2,085 27,395.000 KGM GROSS
# 50.000 MTQ GROSS
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 2 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0002)------------------------------------------------------------------------------------------------------------------
# HLCUANR221245690 SWB ONE 20' X 8' X 8'6" GENERAL PU SLAC
# HL-REF: 35351895 3 DRUMS 666.000 KGM GROSS
# (001) CALCIUM 10%
# SHIPPER: HS-CODE : 28 36 50 0.988 MTQ GROSS
# CHEMICAL PARTNERS AFRICA NV
# KAPELSESTEENWEG 119 3 DRUMS 657.000 KGM GROSS
# 2180 EKEREN (002) ZIRCONIUM 12%
# BELGIUM HS-CODE : 28 25 60 0.975 MTQ GROSS
# CONSIGNEE: 2 DRUMS 436.000 KGM GROSS
# C2CI (003) COBALT 10%
# COULEURS DE COTE D'IVOIRE IMO-CLASS: 9 0.648 MTQ GROSS
# 26 BP 1377 UN-NUMBER: 3082
# ABIDJAN 26 - COTE D'IVOIRE FLASHPOINT: 61.0 C
# PACKING GROUP: 3
# NOTIFY PARTY 1: PROPER SHIPPING NAME:
# C2CI ENVIRONMENTALLY HAZARDOUS
# COULEURS DE COTE D'IVOIRE SUBSTANCE, LIQUID, N.O.S.
# 26 BP 1377
# ABIDJAN 26 - COTE D'IVOIRE HS-CODE : 71 17 11
# PLACE OF RECEIPT (START): 4 DRUMS 795.000 KGM GROSS
# BEANR; ANTWERP (004) METHYL ETHYL KETOXIME (MEKO)
# HS-CODE : 29 14 19 1.180 MTQ GROSS
# PLACE OF DELIVERY (END):
# CIABJ; ABIDJAN 100 BAGS 2,550.000 KGM GROSS
# (005) SODIUM HEXAMETAPHOSPHATE
# HS-CODE : 28 35 29 3.783 MTQ GROSS
# 84 BAGS 2,260.000 KGM GROSS
# (006) ZINC PHOSPHATE
# IMO-CLASS: 9 3.353 MTQ GROSS
# UN-NUMBER: 3077
# PACKING GROUP: 3
# PROPER SHIPPING NAME:
# ENVIRONMENTALLY HAZARDOUS
# SUBSTANCE, SOLID, NOS
# HS-CODE : 28 35 29
# 12 BAGS 307.000 KGM GROSS
# (007) YELLOW MIDDLE CHROME 5080
# IMO-CLASS: 9 0.455 MTQ GROSS
# UN-NUMBER: 3077
# PACKING GROUP: 3
# PROPER SHIPPING NAME:
# ENVIRONMENTALLY HAZARDOUS
# SUBSTANCE, SOLID, NOS
# HS-CODE : 32 04 17
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 3 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUANR221245690 (CONT) 20 BAGS 512.000 KGM GROSS
# (008) YELLOW CHROME LEMON 5064
# IMO-CLASS: 9 0.760 MTQ GROSS
# UN-NUMBER: 3077
# PACKING GROUP: 3
# PROPER SHIPPING NAME:
# ENVIRONMENTALLY HAZARDOUS
# SUBSTANCE, SOLID, NOS
# HS-CODE : 32 04 17
# 12 BAGS 305.000 KGM GROSS
# (009) PIGMENT GREEN 7
# HS-CODE : 32 04 17 0.453 MTQ GROSS
# 4 BAGS 102.000 KGM GROSS
# (010) PIGMENT YELLOW 3
# HS-CODE : 32 06 20 0.153 MTQ GROSS
# 12 BAGS 270.000 KGM GROSS
# (011) PIGMENT RED 112
# HS-CODE : 32 04 17 0.400 MTQ GROSS
# 4 BAGS 42.000 KGM GROSS
# (012) AEROSIL 200
# HS-CODE : 28 11 22 0.063 MTQ GROSS
# 1 DRUM 238.000 KGM GROSS
# (013) NUOSPERSE 2008
# HS-CODE : 34 02 11 0.353 MTQ GROSS
# 20 BAGS 514.000 KGM GROSS
# (014) PIGMENT RED 104
# IMO-CLASS: 9 0.763 MTQ GROSS
# UN-NUMBER: 3077
# PACKING GROUP: 3
# PROPER SHIPPING NAME:
# ENVIRONMENTALLY HAZARDOUS
# SUBSTANCE, SOLID, NOS
# HS-CODE : 32 04 17
# 280 BAGS 7,195.000 KGM GROSS
# (015) TITANIUM DIOXIDE
# HS-CODE : 32 06 11 10.675 MTQ GROSS
# HLBU 1345228 (22G1)
# SEAL NO 1: 1131063
# TARE WEIGHT: 2,350 KGM
# FCL/FCL
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 4 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUANR221245690 (CONT)
# BILL TOTALS 561 16,849.000 KGM GROSS
# 25.002 MTQ GROSS
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 5 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0003)------------------------------------------------------------------------------------------------------------------
# HLCUANR221248560 BL ONE 20' X 8' X 8'6" TANK CONTA SLAC
# HL-REF: 99010904 1 TANK, CYLINDRICAL 21,060.000 KGM GROSS
# (001) UN1294 TOLUENE, 3, II
# SHIPPER: FLASHPOINT: 4 DEG. C. 15.000 MTQ GROSS
# DUTCH2 BV HS-CODE : 29 02 30
# STATIONSWEG 34
# 1441 EJ PURMEREND
# THE NETHERLANDS EKCU 2604784 (22T6)
# SEAL NO 1: 2253353
# CONSIGNEE: SEAL NO 2: 2253389
# SNPC SEAL NO 3: 2257029
# ZONE INDUSTRIELLE DE KOUMASSI SEAL NO 4: CITERNE
# 26 BP 1 ABIDJAN 26 TARE WEIGHT: 4,000 KGM
# IVORY COAST
# FCL/FCL
# NOTIFY PARTY 1:
# SNPC ONE 20' X 8' X 8'6" TANK CONTA SLAC
# ZONE INDUSTRIELLE DE KOUMASSI 1 TANK, CYLINDRICAL 21,040.000 KGM GROSS
# 26 BP 1 ABIDJAN 26 (002) UN1294 TOLUENE, 3, II
# IVORY COAST FLASHPOINT: 4 DEG. C. 15.000 MTQ GROSS
# TEL: 22509922952 HS-CODE : 29 02 30
# NOTIFY PARTY 2:
# CAPEWEST LOGISTICS COTE D'IVOIRE EKCU 2604887 (22T6)
# MARCORY BIETRY ZONE 4 BOULEVARD DE SEAL NO 1: 2631837
# MARSEILLE PRES DE LA STATION SEAL NO 2: 2631838
# SHELL 05 BP 1610 TARE WEIGHT: 4,000 KGM
# ABIDJAN 05-COTE DIVOIRE
# FCL/FCL
# PLACE OF RECEIPT (START):
# BEANR; ANTWERP ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 21,080.000 KGM GROSS
# PLACE OF DELIVERY (END): (003) UN1294 TOLUENE, 3, II
# CIABJ; ABIDJAN FLASHPOINT: 4 DEG. C. 15.000 MTQ GROSS
# 63,18 MT TOLUENE
# 3 X ISO TANKS LOADED WITH TOLUENE
# TOTAL NET WEIGHT: 63180 KGS
# BSC: CIIMP-201150
# FDI NUMBER: 178044
# BASIC RAW MATERIAL FOR LOCAL
# INDUSTRY
# HS-CODE : 29 02 30
# EKCU 2634351 (22T6)
# SEAL NO 1: 2631087
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 6 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUANR221248560 (CONT) BILL TOTALS 3 63,180.000 KGM GROSS
# 45.000 MTQ GROSS
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 7 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0004)------------------------------------------------------------------------------------------------------------------
# HLCUANR221254130 SWB ONE 20' X 8' X 8'6" GENERAL PU SLAC
# HL-REF: 69203385 SILICATE DE 80 DRUMS 23,960.000 KGM GROSS
# SOUDELIQUIDE (001) SODIUM SILICATE 340-4042
# SHIPPER: 340-4042 IN RECONDITIONED PLASTIC DRUMS OF 25.000 MTQ GROSS
# SOLEVO SUISSE MADE IN BELGIUM 285 KG
# 29 ROUTE DE L'AEROPORT BATCH NR.: NET WEIGHT: 22800 KG
# P.O. BOX 236 PRODUCTION DATE: NO DANGEROUS GOODS
# 1215 GENEVA 15 EXPIRY DATE : HS-NO 28391900
# SWITZERLAND + 2 YEARS
# NET WEIGHT:
# CONSIGNEE: 285 KGS
# SOLEVO COTE SOLEVO COTE
# D'IVOIRE SA D'IVOIRE
# RUE DES ABIDJAN
# PETROLIERS SOCH100036822
# ZI DE DEVRIDI 01, HS-CODE : 28 39 19
# BP 107.01 ABIDJAN
# NOTIFY PARTY 1: BSIU 2715931 (22G1)
# SOLEVO COTE SEAL NO 1: 8824718
# D'IVOIRE SA TARE WEIGHT: 2,230 KGM
# RUE DES
# PETROLIERS FCL/FCL
# ZI DE DEVRIDI 01,
# BP 107.01 ABIDJAN ONE 20' X 8' X 8'6" GENERAL PU SLAC
# SILICATE DE 80 DRUMS 23,960.000 KGM GROSS
# PLACE OF RECEIPT (START): SOUDELIQUIDE (002) SODIUM SILICATE 340-4042
# BEANR; ANTWERP 340-4042 IN RECONDITIONED PLASTIC DRUMS OF 25.000 MTQ GROSS
# MADE IN BELGIUM 285 KG
# PLACE OF DELIVERY (END): BATCH NR.: NET WEIGHT: 22800 KG
# CIABJ; ABIDJAN PRODUCTION DATE: NO DANGEROUS GOODS
# EXPIRY DATE : HS-NO 28391900
# + 2 YEARS
# NET WEIGHT:
# 285 KGS
# SOLEVO COTE
# D'IVOIRE
# ABIDJAN
# SOCH10003682
# HS-CODE : 28 39 19
# HLBU 1179955 (22G1)
# SEAL NO 1: 8824710
# TARE WEIGHT: 2,350 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" GENERAL PU SLAC
# SILICATE DE 80 DRUMS 23,960.000 KGM GROSS
# SOUDELIQUIDE (003) SODIUM SILICATE 340-4042
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 8 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUANR221254130 (CONT) 340-4042 IN RECONDITIONED PLASTIC DRUMS OF 25.000 MTQ GROSS
# MADE IN BELGIUM 285 KG
# BATCH NR.: NET WEIGHT: 22800 KG
# PRODUCTION DATE: NO DANGEROUS GOODS
# EXPIRY DATE : HS-NO 28391900
# + 2 YEARS
# NET WEIGHT:
# 285 KGS
# SOLEVO COTE
# D'IVOIRE
# ABIDJAN
# SOCH10003682
# HS-CODE : 28 39 19
# RFCU 2261631 (22G1)
# SEAL NO 1: 8824725
# TARE WEIGHT: 2,200 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" GENERAL PU SLAC
# SILICATE DE 80 DRUMS 23,960.000 KGM GROSS
# SOUDELIQUIDE (004) SODIUM SILICATE 340-4042
# 340-4042 IN RECONDITIONED PLASTIC DRUMS OF 25.000 MTQ GROSS
# MADE IN BELGIUM 285 KG
# BATCH NR.: NET WEIGHT: 22800 KG
# PRODUCTION DATE: NO DANGEROUS GOODS
# EXPIRY DATE : HS-NO 28391900
# + 2 YEARS
# NET WEIGHT:
# 285 KGS
# SOLEVO COTE
# D'IVOIRE
# ABIDJAN
# SOCH10003682
# HS-CODE : 28 39 19
# TEMU 5463600 (22G1)
# SEAL NO 1: 8824708
# TARE WEIGHT: 2,200 KGM
# FCL/FCL
# BILL TOTALS 320 95,840.000 KGM GROSS
# 100.000 MTQ GROSS
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 9 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0005)------------------------------------------------------------------------------------------------------------------
# HLCUANR221262851 SWB ONE 20' X 8' X 8'6" TANK CONTA SLAC
# HL-REF: 26701010 1 TANK, CYLINDRICAL 23,540.000 KGM GROSS
# (001) ALCOOL RYSSEN EXTRA NEUTRE SURFIN 19,960.000 KGM (NET)
# SHIPPER: UN 1170 3 II
# RYSSEN ALCOOLS HS-CODE : 22 07 10 15.000 MTQ GROSS
# PORT 4208
# 59279 LOON PLAGE
# FRANCE ABEU 2604564 (22T6)
# SEAL NO 1: 10940
# CONSIGNEE: SEAL NO 2: 10944
# MIB SEAL NO 3: 10908
# 01 BP 1990 ABIDJAN SEAL NO 4: 10912
# ABIDJAN SEAL NO 5: 10941
# IVORY COAST SEAL NO 6: 10915
# SEAL NO 7: 10909
# NOTIFY PARTY 1: TARE WEIGHT: 4,000 KGM
# MIB
# 01 BP 1990 ABIDJAN FCL/FCL
# ABIDJAN
# IVORY COAST ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 23,690.000 KGM GROSS
# PLACE OF RECEIPT (START): (002) ALCOOL RYSSEN EXTRA NEUTRE SURFIN 20,140.000 KGM (NET)
# BEANR; ANTWERP UN 1170 3 II
# HS-CODE : 22 07 10 15.000 MTQ GROSS
# PLACE OF DELIVERY (END):
# CIABJ; ABIDJAN
# ABEU 2613925 (22T6)
# SEAL NO 1: 10808
# SEAL NO 2: 10834
# SEAL NO 3: 10806
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 23,390.000 KGM GROSS
# (003) ALCOOL RYSSEN EXTRA NEUTRE SURFIN 19,840.000 KGM (NET)
# UN 1170 3 II
# HS-CODE : 22 07 10 15.000 MTQ GROSS
# ABEU 2614393 (22T6)
# SEAL NO 1: 10934
# SEAL NO 2: 10924
# SEAL NO 3: 10925
# SEAL NO 4: CITERNE
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 10 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUANR221262851 (CONT) 1 TANK, CYLINDRICAL 23,660.000 KGM GROSS
# (004) ALCOOL RYSSEN EXTRA NEUTRE SURFIN 20,100.000 KGM (NET)
# UN 1170 3 II
# HS-CODE : 22 07 10 15.000 MTQ GROSS
# ABEU 2617941 (22T6)
# SEAL NO 1: 10951
# SEAL NO 2: 10814
# SEAL NO 3: 10858
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 23,660.000 KGM GROSS
# (005) ALCOOL RYSSEN EXTRA NEUTRE SURFIN 20,100.000 KGM (NET)
# UN 1170 3 II
# HS-CODE : 22 07 10 15.000 MTQ GROSS
# ABEU 2618043 (22T6)
# SEAL NO 1: 10817
# SEAL NO 2: 10810
# SEAL NO 3: 10829
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# BILL TOTALS 5 117,940.000 KGM GROSS
# 75.000 MTQ GROSS
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 11 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0006)------------------------------------------------------------------------------------------------------------------
# HLCUANR221264338 BL ONE 40' X 8' X 9'6" REEFER CON SLAC
# HL-REF: 20733864 1,764 CARTON(S) 26,134.000 KGM GROSS
# (001) 756 CARTONS GERMAN FROZEN BEEF FEET
# SHIPPER: 1.008 CARTONS GERMAN FROZEN BEEF 50.000 MTQ GROSS
# NOWACO SHIPPING APS TRIPES
# PRINSENSGADE 15, 3. WITH HONEYCOMB
# P.O.BOX 40
# DK-9100 AALBORG 25.200 KG NET
# DENMARK
# BSC #CIIMP-210181
# CONSIGNEE: HS-CODE : 02 06 49
# POISSON D'AFRIQUE
# 21 BP 1757 ABJ 21
# BD PRINCIPAL FACE FIGAYO YOP HLBU 9230971 (45R1)
# ABIDJAN SEAL NO 1: HB238237
# IVORY COAST TARE WEIGHT: 4,410 KGM
# NOTIFY PARTY 1: FCL/FCL
# POISSON D'AFRIQUE
# 21 BP 1757 ABJ 21
# BD PRINCIPAL FACE FIGAYO YOP BILL TOTALS 1,764 26,134.000 KGM GROSS
# ABIDJAN 50.000 MTQ GROSS
# IVORY COAST
# NOTIFY PARTY 2:
# NOWACO SHIPPING APS
# PRINSENSGADE 15, P.O.BOX 40
# DK - 9100 AALBORG
# PLACE OF RECEIPT (START):
# DECRH; CRAILSHEIM
# PLACE OF DELIVERY (END):
# CIABJ; ABIDJAN
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 12 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0007)------------------------------------------------------------------------------------------------------------------
# HLCUANR230103155 SWB ONE 20' X 8' X 8'6" TANK CONTA SLAC
# HL-REF: 33685668 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (001) CLEAN & EMPTY TANK
# SHIPPER: TARE: 3750 15.000 MTQ GROSS
# VAN DEN BOSCH DMCC HS-CODE : 86 09 00
# MAZAYA BB1 - UNIT #4107,
# JLT MAZAYA BUSINESS AVENUE
# DUBAI UNITED ARAB EMIRATES ABEU 2601251 (22T0)
# SEAL NO 1: N/A
# CONSIGNEE: TARE WEIGHT: 4,000 KGM
# CAPEWEST LOGISTICS COTE D'IVOIRE
# MARCORY BIETRY ZONE 4 BOULEVARD DE FCL/FCL
# MARSEILLE PRES DE LA STATION
# SHELL 05 BP 1610 ONE 20' X 8' X 8'6" TANK CONTA SLAC
# ABIDJAN 05-COTE DIVOIRE 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (002) CLEAN & EMPTY TANK
# NOTIFY PARTY 1: TARE: 3550 15.000 MTQ GROSS
# CAPEWEST LOGISTICS COTE D'IVOIRE HS-CODE : 86 09 00
# MARCORY BIETRY ZONE 4 BOULEVARD DE
# MARSEILLE PRES DE LA STATION
# SHELL 05 BP 1610 ABEU 2614325 (22T0)
# ABIDJAN 05-COTE DIVOIRE SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# PLACE OF RECEIPT (START):
# BEANR; ANTWERP FCL/FCL
# PLACE OF DELIVERY (END): ONE 20' X 8' X 8'6" TANK CONTA SLAC
# CIABJ; ABIDJAN 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (003) CLEAN & EMPTY TANK
# TARE: 3560 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2615830 (22T0)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (004) CLEAN & EMPTY TANK
# TARE: 3560 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2615867 (22T0)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 13 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUANR230103155 (CONT)
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (005) CLEAN & EMPTY TANK
# TARE: 3560 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2616360 (22T0)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (006) CLEAN & EMPTY TANK
# TARE: 3560 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2616605 (22T0)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (007) CLEAN & EMPTY TANK
# TARE: 3560 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2616816 (22T0)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (008) CLEAN & EMPTY TANK
# TARE: 3560 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2616863 (22T0)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 14 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUANR230103155 (CONT)
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (009) CLEAN & EMPTY TANK
# TARE: 3560 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2616992 (22T0)
# SEAL NO 1: N/A
# SEAL NO 2: 12470650
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (010) CLEAN & EMPTY TANK
# TARE: 3560 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2618212 (22T0)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# BILL TOTALS 10 10.000 KGM GROSS
# 150.000 MTQ GROSS
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 15 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0008)------------------------------------------------------------------------------------------------------------------
# HLCUANR230103166 SWB ONE 20' X 8' X 8'6" TANK CONTA SLAC
# HL-REF: 12045988 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (001) CLEAN & EMPTY TANK
# SHIPPER: TARE: 3620 15.000 MTQ GROSS
# VAN DEN BOSCH DMCC HS-CODE : 86 09 00
# MAZAYA BB1 - UNIT #4107,
# JLT MAZAYA BUSINESS AVENUE
# DUBAI UNITED ARAB EMIRATES ABEU 2602751 (22T6)
# SEAL NO 1: N/A
# CONSIGNEE: TARE WEIGHT: 3,620 KGM
# CAPEWEST LOGISTICS COTE D'IVOIRE
# MARCORY BIETRY ZONE 4 BOULEVARD DE FCL/FCL
# MARSEILLE PRES DE LA STATION
# SHELL 05 BP 1610 ONE 20' X 8' X 8'6" TANK CONTA SLAC
# ABIDJAN 05-COTE DIVOIRE 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (002) CLEAN & EMPTY TANK
# NOTIFY PARTY 1: TARE: 3620 15.000 MTQ GROSS
# CAPEWEST LOGISTICS COTE D'IVOIRE HS-CODE : 86 09 00
# MARCORY BIETRY ZONE 4 BOULEVARD DE
# MARSEILLE PRES DE LA STATION
# SHELL 05 BP 1610 ABEU 2603634 (22T0)
# ABIDJAN 05-COTE DIVOIRE SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# PLACE OF RECEIPT (START):
# BEANR; ANTWERP FCL/FCL
# PLACE OF DELIVERY (END): ONE 20' X 8' X 8'6" TANK CONTA SLAC
# CIABJ; ABIDJAN 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (003) CLEAN & EMPTY TANK
# TARE: 3580 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2609890 (22T1)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (004) CLEAN & EMPTY TANK
# TARE: 3550 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2612699 (22T0)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 16 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUANR230103166 (CONT)
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (005) CLEAN & EMPTY TANK
# TARE: 3550 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2614388 (22T3)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (006) CLEAN & EMPTY TANK
# TARE: 3550 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2614916 (22T1)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (007) CLEAN & EMPTY TANK
# TARE: 3560 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2615492 (22T2)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (008) CLEAN & EMPTY TANK
# TARE: 3560 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2615532 (22T6)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 17 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUANR230103166 (CONT)
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (009) CLEAN & EMPTY TANK
# TARE: 3560 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2615640 (22T6)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 1.000 KGM GROSS
# (010) CLEAN & EMPTY TANK
# TARE: 3740 15.000 MTQ GROSS
# HS-CODE : 86 09 00
# ABEU 2629686 (22T3)
# SEAL NO 1: N/A
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# BILL TOTALS 10 10.000 KGM GROSS
# 150.000 MTQ GROSS
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 18 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0009)------------------------------------------------------------------------------------------------------------------
# HLCUANR230108634 SWB ONE 40' X 8' X 9'6" HIGH CUBE SLAC
# HL-REF: 65538574 1 LOT 12,000.000 KGM GROSS
# (001) OF USED CAR SPARE PARTS 12,000.000 KGM (NET)
# SHIPPER: HS-CODE : 87 08 99
# KORRI EXPORT IMPORT SAL OFFSHORE 50.000 MTQ GROSS
# JNAH, NEW AIRPORT ROAD
# AL HANAA BLDG GESU 6479702 (45G1)
# BEIRUT/LEBANON SEAL NO 1: 0403994
# PHONE: +961 1 391061 SEAL NO 2: 403994
# TARE WEIGHT: 3,830 KGM
# CONSIGNEE:
# GENERAL AUTO PARTS FCL/FCL
# MARCORY ZONE 4C, RUE DU CANAL
# ABIDJAN
# IVORY COAST BILL TOTALS 1 12,000.000 KGM GROSS
# PHONE: +225 21241404 / 09718171 50.000 MTQ GROSS
# NOTIFY PARTY 1:
# GENERAL AUTO PARTS
# MARCORY ZONE 4C, RUE DU CANAL
# ABIDJAN
# IVORY COAST
# PHONE: +225 21241404 / 09718171
# PLACE OF RECEIPT (START):
# BEANR; ANTWERP
# PLACE OF DELIVERY (END):
# CIABJ; ABIDJAN
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 19 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0010)------------------------------------------------------------------------------------------------------------------
# HLCUANR230110405 SWB ONE 20' X 8' X 8' TANK CONTAIN SLAC
# HL-REF: 85812240 1 TANK, CYLINDRICAL 15,440.000 KGM GROSS
# (001) HEXANE
# SHIPPER: PROPER SHIPPING NAME: 15.000 MTQ GROSS
# KH CHEMICALS BV UN1208 HEXANES, 3, II
# SCHEEPMAKERIJ 260 (-27 DEG. C.), MARINE POLLUTANT
# 3331 MB ZWIJNDRECHT EMS: F-E, S-D
# THE NETHERLANDS
# BSC : CIIMP-206250
# CONSIGNEE: BASIC RAW MATERIAL FOR LOCAL
# SOCIETE POUR LE COMPOUNDAGE EN COTE INDUSTRY
# D'IVOIRE (SCCI) HS-CODE : 29 01 10
# ZONE INDUSTRIELLE DE VRIDI
# 01 BP 3622 ABIDJAN 01
# IVORY COAST ABEU 2531386 (20T3)
# SEAL NO 1: 31610373
# NOTIFY PARTY 1: SEAL NO 2: 31610372
# SOCIETE POUR LE COMPOUNDAGE EN COTE SEAL NO 3: 31610371
# D'IVOIRE (SCCI) TARE WEIGHT: 4,000 KGM
# ZONE INDUSTRIELLE DE VRIDI
# 01 BP 3622 ABIDJAN 01 IVORY COAST FCL/FCL
# PLACE OF RECEIPT (START): ONE 20' X 8' X 8' TANK CONTAIN SLAC
# BEANR; ANTWERP 1 TANK, CYLINDRICAL 15,960.000 KGM GROSS
# (002) HEXANE
# PLACE OF DELIVERY (END): 15.000 MTQ GROSS
# CIABJ; ABIDJAN UN1208 HEXANES, 3, II
# HS-CODE : 29 01 10
# ABEU 2628289 (20T3)
# SEAL NO 1: 7869641
# SEAL NO 2: 7869642
# SEAL NO 3: 7869643
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8' TANK CONTAIN SLAC
# 1 TANK, CYLINDRICAL 15,950.000 KGM GROSS
# (003) HEXANE
# 15.000 MTQ GROSS
# UN1208 HEXANES, 3, II
# HS-CODE : 29 01 10
# ABEU 2633048 (20T3)
# SEAL NO 1: 7869602
# SEAL NO 2: 7869603
# SEAL NO 3: 7869604
# TARE WEIGHT: 4,000 KGM
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 20 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUANR230110405 (CONT)
# FCL/FCL
# ONE 20' X 8' X 8' TANK CONTAIN SLAC
# 1 TANK, CYLINDRICAL 15,950.000 KGM GROSS
# (004) HEXANE
# 15.000 MTQ GROSS
# UN1208 HEXANES, 3, II
# HS-CODE : 29 01 10
# CJTU 2702400 (20T3)
# SEAL NO 1: 7869605
# SEAL NO 2: 7869606
# SEAL NO 3: 7869607
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8' TANK CONTAIN SLAC
# 1 TANK, CYLINDRICAL 15,960.000 KGM GROSS
# (005) HEXANE
# 15.000 MTQ GROSS
# UN1208 HEXANES, 3, II
# HS-CODE : 29 01 10
# CJTU 2702606 (20T3)
# SEAL NO 1: 27547804
# SEAL NO 2: 27547805
# SEAL NO 3: 27547806
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8' TANK CONTAIN SLAC
# 1 TANK, CYLINDRICAL 15,900.000 KGM GROSS
# (006) HEXANE
# 15.000 MTQ GROSS
# UN1208 HEXANES, 3, II
# HS-CODE : 29 01 10
# EKCU 2604640 (20T3)
# SEAL NO 1: 27547804
# SEAL NO 2: 27547805
# SEAL NO 3: 27547806
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8' TANK CONTAIN SLAC
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 21 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUANR230110405 (CONT) 1 TANK, CYLINDRICAL 15,950.000 KGM GROSS
# (007) HEXANE
# 15.000 MTQ GROSS
# UN1208 HEXANES, 3, II
# HS-CODE : 29 01 10
# JBTU 2801431 (20T3)
# SEAL NO 1: 3106281
# SEAL NO 2: 3106282
# SEAL NO 3: 3106283
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# BILL TOTALS 7 111,110.000 KGM GROSS
# 105.000 MTQ GROSS
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 22 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0011)------------------------------------------------------------------------------------------------------------------
# HLCUANR230111620 SWB ONE 40' X 8' X 9'6" REEFER CON SLAC
# HL-REF: 11020146 2,569 CARTONS 27,241.000 KGM GROSS
# (001) FROZEN PORK TONGUE ROOT
# SHIPPER: NW: 25690 KGS 40.000 MTQ GROSS
# ELFERING EXPORT GMBH BSC CIIMP- 208635
# P/C WF DISTRIBUTION SASU HS-CODE : 02 03 22
# 76 AVENUE MARECHAL FOCH
# CAPBRETON 40130
# FRANCE BMOU 9213354 (45R1)
# SEAL NO 1: 0023567
# CONSIGNEE: TARE WEIGHT: 4,640 KGM
# SOCOCI
# TREICHVILLE FCL/FCL
# BOULEVARD VGE
# ABIDJAN 03 BP 1590
# COTE D'IVOIRE BILL TOTALS 2,569 27,241.000 KGM GROSS
# 40.000 MTQ GROSS
# NOTIFY PARTY 1:
# SOCOCI
# TREICHVILLE
# BOULEVARD VGE
# ABIDJAN 03 BP 1590
# COTE D'IVOIRE
# PLACE OF RECEIPT (START):
# BEANR; ANTWERP
# PLACE OF DELIVERY (END):
# CIABJ; ABIDJAN
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 23 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0012)------------------------------------------------------------------------------------------------------------------
# HLCUANR230112265 SWB ONE 20' X 8' X 8'6" TANK CONTA SLAC
# HL-REF: 16006340 1 TANK, CYLINDRICAL 19,520.000 KGM GROSS
# (001) ETHYL ALCOHOL 96 %
# SHIPPER: HS-CODE : 22 07 20 15.000 MTQ GROSS
# VAN DEN BOSCH DMCC
# HOOGVEN 10
# EM ERP ABEU 2601441 (22T4)
# 5469 NETHERLANDS SEAL NO 1: S0000108
# SEAL NO 2: S0000109
# CONSIGNEE: SEAL NO 3: S0000110
# MANUFACTURE IVORIENNE DE BOISSONS TARE WEIGHT: 4,000 KGM
# 01 B.P. 1990 ABIDJAN 01
# Z INDUSTRIELLE DE KOUMASSI FCL/FCL
# COTE D'IVORE
# +22508858268 ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 19,800.000 KGM GROSS
# NOTIFY PARTY 1: (002) ETHYL ALCOHOL 96 %
# CAPEWEST LOGISTICS COTE D'IVOIRE UN: 1170 ETHANOL (ETHYL ALCOHOL) 15.000 MTQ GROSS
# MARCORY BIETRY ZONE 4 BOULEVARD DE CLASS: 3 PG: II FLASHPOINT: 13 C
# MARSEILLE PRES DE LA STATION (CLOSED CUP)
# SHELL 05 BP 1610 MARINE POLLUTANT: NO
# ABIDJAN 05-COTE DIVOIRE HS-CODE : 22 07 20
# PLACE OF RECEIPT (START):
# BEANR; ANTWERP ABEU 2630795 (22T4)
# SEAL NO 1: N0045315
# PLACE OF DELIVERY (END): SEAL NO 2: N0045316
# CIABJ; ABIDJAN SEAL NO 3: N0045317
# SEAL NO 4: N0045318
# SEAL NO 5: N0045319
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 19,680.000 KGM GROSS
# (003) ETHYL ALCOHOL 96 %
# HS-CODE : 22 07 20 15.000 MTQ GROSS
# ABEU 2630835 (22T3)
# SEAL NO 1: S0000116
# SEAL NO 2: S0000117
# SEAL NO 3: S0000118
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 19,600.000 KGM GROSS
# (004) ETHYL ALCOHOL 96 %
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 24 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUANR230112265 (CONT) HS-CODE : 22 07 20 15.000 MTQ GROSS
# ABEU 2630970 (22T3)
# SEAL NO 1: S0000081
# SEAL NO 2: S0000082
# SEAL NO 3: S0000083
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# ONE 20' X 8' X 8'6" TANK CONTA SLAC
# 1 TANK, CYLINDRICAL 19,840.000 KGM GROSS
# (005) ETHYL ALCOHOL 96 %
# HS-CODE : 22 07 20 15.000 MTQ GROSS
# ABEU 2631472 (22T4)
# SEAL NO 1: N0045320
# SEAL NO 2: N0045321
# SEAL NO 3: N0045322
# TARE WEIGHT: 4,000 KGM
# FCL/FCL
# BILL TOTALS 5 98,440.000 KGM GROSS
# 75.000 MTQ GROSS
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 25 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0013)------------------------------------------------------------------------------------------------------------------
# HLCUANR230115179 SWB ONE 40' X 8' X 9'6" REEFER CON SLAC
# HL-REF: 25735667 2,487 CARTONS 25,653.405 KGM GROSS
# (001) FROZEN FRIES / FRITES CONGELEES
# SHIPPER: NW: 24870 KGS 40.000 MTQ GROSS
# S.C.G. SAS BESC: CIIMP-175494
# 143 AVENUE DE KERADENNEC FDI : 149333
# 29000 QUIMPER HS-CODE : 20 04 10
# FRANCE
# CONSIGNEE: FSCU 5662082 (45R1)
# SA SANGEL CI SEAL NO 1: 9343048
# RUE DE LA POINTE AU FUMEURS ZI TARE WEIGHT: 4,640 KGM
# VRIDI 15BP ABIDJAN
# COTE D IVOIRE FCL/FCL
# NOTIFY PARTY 1:
# SA SANGEL CI BILL TOTALS 2,487 25,653.405 KGM GROSS
# RUE DE LA POINTE AU FUMEURS ZI 40.000 MTQ GROSS
# VRIDI 15BP ABIDJAN
# COTE D IVOIRE
# PLACE OF RECEIPT (START):
# BEANR; ANTWERP
# PLACE OF DELIVERY (END):
# CIABJ; ABIDJAN
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 26 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0014)------------------------------------------------------------------------------------------------------------------
# HLCUANR230122513 SWB ONE 40' X 8' X 8'6" GENERAL PU SLAC
# HL-REF: 43996376 ANYA/1141/2022 4 COLIS 1,129.600 KGM GROSS
# BRASSIVOIRE (001) SPARE PART /
# SHIPPER: ABIDJAN PIECES DE RECHANGE 5.850 MTQ GROSS
# IBECOR N.V. COTE D IVOIRE
# INTERNATIONAL BEVERAGES CORPORATION VIA ABIDJAN
# CHAUSSEE DE LA HULPE 177, BTE 4 HS-CODE : 84 31 39
# 1170 BRUXELLES
# BELGIUM ANYA/1034/2022 6 COLIS 1,252.800 KGM GROSS
# BRASSIVOIRE (002) SPARE PARTS /
# CONSIGNEE: ABIDJAN PIECES DE RECHANGE 5.359 MTQ GROSS
# BRASSIVOIRE COTE D IVOIRE
# 01 BP 5473 VIA ABIDJAN
# . HS-CODE : 84 31 39
# ABIDJAN 01
# COTE D IVOIRE
# HLBU 1248038 (42G1)
# NOTIFY PARTY 1: SEAL NO 1: 172822
# BOLLORE TRANSPORT & LOGISTICS COTE TARE WEIGHT: 3,700 KGM
# D IVOIRE, AVENUE CHRISTIANI,
# TREICHVILLE, 01 B.P. 1727 FCL/FCL
# ABIDJAN 01
# COTE D IVOIRE
# BILL TOTALS 10 2,382.400 KGM GROSS
# PLACE OF RECEIPT (START): 11.209 MTQ GROSS
# BEANR; ANTWERP
# PLACE OF DELIVERY (END):
# CIABJ; ABIDJAN
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 27 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0015)------------------------------------------------------------------------------------------------------------------
# HLCUBEL221203383 SWB ONE 40' X 8' X 9'6" REEFER CON SLAC
# HL-REF: 23675087 1,330 CARTONS 25,800.000 KGM GROSS
# (001) FROZEN PORK HEADS
# SHIPPER: NET WEIGHT: 24960.98KGS 50.000 MTQ GROSS
# NORWEST FOODS INTERNATIONAL LTD HS-CODE : 02 03 21
# 3 HAIG COURT, HAIG ROAD, KNUTSFORD,
# CHESHIRE, WA16 8XZ, UNITED KINGDOM
# GB TCLU 1271582 (45R1)
# SEAL NO 1: DAFMA508679
# CONSIGNEE: SEAL NO 2: DAFMA50867
# ALCO FOODS SARL TARE WEIGHT: 4,460 KGM
# PORT BOUET ABIDJAN
# 05 BP 3448 FCL/FCL
# COTE D'IVOIRE
# NOTIFY PARTY 1: BILL TOTALS 1,330 25,800.000 KGM GROSS
# ALCO FOODS SARL 50.000 MTQ GROSS
# PORT BOUET ABIDJAN
# 05 BP 3448
# COTE D'IVOIRE
# PLACE OF RECEIPT (START):
# IEDUB; DUBLIN, IRELAND
# PLACE OF DELIVERY (END):
# CIABJ; ABIDJAN
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 28 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0016)------------------------------------------------------------------------------------------------------------------
# HLCUBEL221204616 SWB ONE 40' X 8' X 9'6" REEFER CON SLAC
# HL-REF: 23377407 1,932 CARTONS 27,288.230 KGM GROSS
# (001) FROZEN BEEF FEET RSA 627 CASES
# SHIPPER: (NET) 50.000 MTQ GROSS
# FOYLE FOOD GROUP LTD ON BEHALF OF 12502.96KGS (GROSS) 13255.36KGS
# WORLD FOOD DISTRIBUTION LTD FROZEN BEEF MUZZLES 547 CASES
# ROOM 612, 6/F HONG KONG MAN (NET)
# INDUSTRIAL CENTRE, 2 HONG MAN 5372.53KGS (GROSS) 5821.07KGS
# STREET, CHAI WAN, HONG KONG FROZEN BEEF FEET 24 CASES (NET)
# 480KGS (GROSS) 508.80KGS
# CONSIGNEE: FROZEN BEEF LIVER 206 CASES (NET)
# SOCOCI 2044.46KGS (GROSS) 2213.38KGS
# TREICHVILLE BLVD VGE FROZEN BEEF TRACHEA BALLS 13 CASES
# 03 BP 1590
# ABIDJAN 18 (NET)
# COTE D'IVOIRE 110.84KGS (GROSS) 125.14KGS
# FROZEN BEEF TRACHEA BALLS 515
# NOTIFY PARTY 1: CASES (NET)
# SOCOCI 4942.18KGS (GROSS) 5364.48KGS)
# TREICHVILLE BLVD VGE TOTAL 1932 CASES
# 03 BP 1590 FREIGHT PREPAID
# ABIDJAN 18 TOTAL NET WEIGHT: 25452.97KGS
# COTE D'IVOIRE HS-CODE : 84 83 90
# PLACE OF RECEIPT (START):
# GBBEL; BELFAST, NORTHERN IRELAND TRIU 8179615 (45R1)
# SEAL NO 1: DAERA0558068
# PLACE OF DELIVERY (END): SEAL NO 2: DAERA05580
# CIABJ; ABIDJAN TARE WEIGHT: 4,670 KGM
# FCL/FCL
# BILL TOTALS 1,932 27,288.230 KGM GROSS
# 50.000 MTQ GROSS
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 29 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0017)------------------------------------------------------------------------------------------------------------------
# HLCUBSC2211BSWI0 SWB ONE 20' X 8' X 8'6" GENERAL PU SLAC
# HL-REF: 67865391 2,940 CONTAINER, NOT OTHERW. SPECIF. AS T 4,000.000 KGM GROSS
# (001) 400 COLIS DE TAM-TAM
# SHIPPER: 2540 OEAN DE CHIEVRES ET DE BOEUFS 33.200 MTQ GROSS
# SABIN V LLC D/B/A DJEMBE DRUMS & HS CODE 95 03 00
# SKINS HS-CODE : 95 03 00
# EIN#85-345379 RORY BAKER
# SEVIERVILLE ZIP 37862
# TRHU 1917502 (22G1)
# CONSIGNEE: SEAL NO 1: .
# SAKO MAMADY SEAL NO 2: HLG1560398
# 19 BP 832NABIDJAN 19 TARE WEIGHT: 2,180 KGM
# CTE D'IVOIRE
# +225 05-05-04-95-31 FCL/FCL
# PLACE OF RECEIPT (START):
# USSAV; SAVANNAH, GA BILL TOTALS 2,940 4,000.000 KGM GROSS
# 33.200 MTQ GROSS
# PLACE OF DELIVERY (END):
# CIABJ; ABIDJAN
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 30 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0018)------------------------------------------------------------------------------------------------------------------
# HLCUBSC221177740 SWB ONE 20' X 8' X 8'6" GENERAL PU SLAC
# HL-REF: 69848523 1 VEHICLE 1,738.620 KGM GROSS
# (001) CONTAINING : AUTO
# SHIPPER: FOR ALPHA DIALLO. 16.129 MTQ GROSS
# SEA EXPRESS AMERICA CORP NO COMMERCIAL VALUE, NOT FOR
# 514 NORTH ACADEMY STREET RESALE.
# LINCOLNTON NC, US 28092 PKGING: AUTO
# T: 704 732 6063 F: 704 732 6383 AUTO DETAILS:
# EIN: 562087854 MAKE / MODEL:
# NISSAN MURANO
# CONSIGNEE: YEAR /COLOR: 2022 GRAY /
# AMERICAN AMBASSADOR AMERICAN VIN #: 5N1AZ2AJ3NC129056
# EMBASSY ASD
# BP 730 ABIDJAN CIDEX 03 VEHICLE HAS LESS THAN ONE QUARTER
# ABIDJAN, COTE D'IVOIRE TANK OF FUEL AND
# T: 225 22 49 40 00 THE BATTERY HAS BEEN DISCONNECTED
# POC: SHIPPING & CUSTOMS
# CTN: BSC # CIIMP-185176
# NOTIFY PARTY 1: HS-CODE : 73 09 00
# PACKING SERVICE
# T: 2252125 27 17
# EMAIL: DEMENAGEMENT@ UETU 2827427 (22G1)
# PACKINGSERVICE.COM SEAL NO 1: 015336
# SEAL NO 2: 0411384
# PLACE OF RECEIPT (START): TARE WEIGHT: 2,100 KGM
# USBAL; BALTIMORE, MD
# FCL/FCL
# PLACE OF DELIVERY (END):
# CIABJ; ABIDJAN
# BILL TOTALS 1 1,738.620 KGM GROSS
# 16.129 MTQ GROSS
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 31 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(0019)------------------------------------------------------------------------------------------------------------------
# HLCUCA4221150728 BL ONE 40' X 8' X 9'6" HIGH CUBE SLAC
# HL-REF: 65531093 N/M 1,280 CARTONS 9,277.600 KGM GROSS
# (001) STAND FAN
# SHIPPER: HS-CODE : 84 14 51 63.000 MTQ GROSS
# ZHONGSHAN DOUBLE CROWN ELECTRICAL
# APPLIANCE CO.,LTD
# NO.10 JIANLONG STREET,JI DONG FANU 1959207 (45G1)
# TWO,XIAO LAN TOWN, ZHONG SHAN SEAL NO 1: HLG4789737
# CITY,GUANG DONG TARE WEIGHT: 3,680 KGM
# TEL:+86-0760-22187308
# FCL/FCL
# CONSIGNEE:
# S.A.T.D ONE 40' X 8' X 9'6" HIGH CUBE SLAC
# SOCIETE AFRICAINE DE TOLES ET N/M 1,163 CARTONS 7,759.700 KGM GROSS
# DERIVES (002) STAND FAN
# NO CC: 2157962 V HS-CODE : 84 14 51 63.000 MTQ GROSS
# 13 BP 1045 ABIDJAN 13
# TEL:0709000057
# FFAU 1233360 (45G1)
# NOTIFY PARTY 1: SEAL NO 1: HLG4784670
# SAME AS CONSINGEE SEAL NO 2: 4784670
# TARE WEIGHT: 3,700 KGM
# PLACE OF RECEIPT (START):
# CNDCB; DA CHAN BAY FCL/FCL
# PLACE OF DELIVERY (END): ONE 40' X 8' X 9'6" HIGH CUBE SLAC
# CIABJ; ABIDJAN N/M 1,190 CARTONS 9,365.600 KGM GROSS
# (003) STAND FAN
# HS-CODE : 84 14 51 67.000 MTQ GROSS
# HLBU 1327944 (45G1)
# SEAL NO 1: HLG4781332
# TARE WEIGHT: 3,900 KGM
# FCL/FCL
# ONE 40' X 8' X 9'6" HIGH CUBE SLAC
# N/M 1,190 CARTONS 9,449.300 KGM GROSS
# (004) STAND FAN
# HS-CODE : 84 14 51 66.000 MTQ GROSS
# HLXU 8065397 (45G1)
# SEAL NO 1: HLG4789713
# TARE WEIGHT: 3,950 KGM
# FCL/FCL
# ONE 40' X 8' X 9'6" HIGH CUBE SLAC
# N/M 1,247 CARTONS 10,952.400 KGM GROSS
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 32 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUCA4221150728 (CONT) (005) STAND FAN
# HS-CODE : 84 14 51 63.000 MTQ GROSS
# HLXU 8275120 (45G1)
# SEAL NO 1: HLG4784511
# TARE WEIGHT: 3,900 KGM
# FCL/FCL
# ONE 40' X 8' X 9'6" HIGH CUBE SLAC
# N/M 1,123 CARTONS 7,909.600 KGM GROSS
# (006) STAND FAN
# HS-CODE : 84 14 51 63.000 MTQ GROSS
# SEGU 5800237 (45G1)
# SEAL NO 1: HLG4789559
# TARE WEIGHT: 3,830 KGM
# FCL/FCL
# ONE 40' X 8' X 9'6" HIGH CUBE SLAC
# N/M 1,210 CARTONS 9,281.800 KGM GROSS
# (007) STAND FAN
# HS-CODE : 84 14 51 65.000 MTQ GROSS
# SEKU 6367384 (45G1)
# SEAL NO 1: HLG4789667
# TARE WEIGHT: 3,700 KGM
# FCL/FCL
# ONE 40' X 8' X 9'6" HIGH CUBE SLAC
# N/M 1,154 CARTONS 7,582.400 KGM GROSS
# (008) STAND FAN
# HS-CODE : 84 14 51 65.000 MTQ GROSS
# TCNU 1752815 (45G1)
# SEAL NO 1: HLG4781268
# TARE WEIGHT: 3,700 KGM
# FCL/FCL
# ONE 40' X 8' X 9'6" HIGH CUBE SLAC
# N/M 1,160 CARTONS 7,702.400 KGM GROSS
# (009) STAND FAN
# HS-CODE : 84 14 51 64.000 MTQ GROSS
# THIS B/L CONTINUED ON NEXT PAGE
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 33 / 266
# ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME
# -----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------
# HLCUCA4221150728 (CONT) TRLU 7501254 (45G1)
# SEAL NO 1: HLG4789574
# TARE WEIGHT: 3,880 KGM
# FCL/FCL
# ONE 40' X 8' X 9'6" HIGH CUBE SLAC
# N/M 1,169 CARTONS 8,643.200 KGM GROSS
# (010) STAND FAN
# HS-CODE : 84 14 51 66.000 MTQ GROSS
# TXGU 7179426 (45G1)
# SEAL NO 1: HLG4789680
# TARE WEIGHT: 3,700 KGM
# FCL/FCL
# ONE 40' X 8' X 9'6" HIGH CUBE SLAC
# N/M 1,178 CARTONS 7,040.400 KGM GROSS
# (011) STAND FAN
# HS-CODE : 84 14 51 63.000 MTQ GROSS
# UACU 5981405 (45G1)
# SEAL NO 1: HLG4781278
# TARE WEIGHT: 3,800 KGM
# FCL/FCL
# BILL TOTALS 13,064 94,964.400 KGM GROSS
# 708.000 MTQ GROSS
# ...
# P O R T S U M M A R Y
# TOTAL DOCUMENTS: 87 TOTAL PACKAGES: 136131 TOTAL GROSS WEIGHT: 4189880 KGM TOTAL VOLUME: 106121 MTQ
# TOTAL FREIGHT TONS: 106121 FTN
# ONE HUNDRED AND THIRTY-SIX THOUSAND AND ONE HUNDRED AND THIRTY-ONE PACKAGES ONLY
# TOTAL FULL 20' : 54
# TOTAL FULL 40' : 156
# TOTAL EMPTY 20' : 0
# TOTAL EMPTY 40' : 0
# -----------------------------------------------------------------------------------------------------------------------------------
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 262 / 266
# ABIDJAN VESSEL: MARTHA A POL: TANGER MED LOADING: 2023-01-21 06:36 DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-21 21:00 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# ====================================================================================================================================
# == ==
# == C O N T A I N E R S U M M A R Y ==
# == ==
# ====================================================================================================================================
# == ==
# == 20' CONTAINER UNIT TYPE TARE WEIGHT GROSS WEIGHT 1.SEAL-NO LAST SEAL-NO TEMPERATURE SETTING OUT OF GAUGE E/F ==
# == --------------------------------------------------------------------------------------------------------------------------- ==
# == HAMU 1123581 22G1 2300 KGM 3138 KGM HLD1881495 HLD1881490 F ==
# == TRHU 1615694 22G1 2230 KGM 15160 KGM HLD1910713 F ==
# == FCIU 6308264 22G1 2250 KGM 28870 KGM 3000721 KLIK202573 F ==
# == HLXU 1133967 22G1 2350 KGM 28920 KGM 3000722 KLIK202573 F ==
# == HLXU 1348395 22G1 2350 KGM 28900 KGM 3000723 KLIK202573 F ==
# == HLXU 1416735 22G1 2350 KGM 28880 KGM 3000724 KLIK202573 F ==
# == TCLU 3195096 22G1 2200 KGM 28790 KGM 3000725 KLIK202573 F ==
# == TCLU 3293739 22G1 2200 KGM 28760 KGM 3000726 KLIK202573 F ==
# == TLLU 2452243 22G1 2100 KGM 28640 KGM 3000727 KLIK202573 F ==
# == UACU 3438657 22G1 2320 KGM 28920 KGM 3000728 KLIK202573 F ==
# == UACU 3738886 22G1 2300 KGM 28800 KGM 3000729 KLIK202573 F ==
# == UACU 4099563 22G1 2300 KGM 28810 KGM 3000730 KLIK202573 F ==
# == FCIU 6556698 22G1 2100 KGM 28674 KGM HLG3172574 F ==
# == HLBU 1001198 22G1 2350 KGM 28924 KGM HLG3172575 F ==
# == HLXU 1167859 22G1 2350 KGM 28924 KGM HLG3172576 F ==
# == HLXU 1291387 22G1 2350 KGM 28924 KGM HLG3172577 F ==
# == TCLU 3086726 22G1 2200 KGM 28774 KGM HLG3172578 F ==
# == TCLU 3708901 22G1 2200 KGM 28774 KGM HLG3172579 3172579 F ==
# == TCLU 3712012 22G1 2200 KGM 28774 KGM HLG3172580 F ==
# == TEMU 1399800 22G1 2100 KGM 28774 KGM HLG3172581 3172581 F ==
# == TEMU 4329432 22G1 2200 KGM 28774 KGM HLG3172582 F ==
# == UACU 3411960 22G1 2320 KGM 28894 KGM HLG3172583 F ==
# == FBIU 0444889 22G1 2100 KGM 22100 KGM HLG4006392 F ==
# == UACU 3684033 22G1 2330 KGM 4540 KGM P4856298 F ==
# == HLXU 1024539 22G1 2350 KGM 3660 KGM HLD6033205 F ==
# == TEMU 1456270 22G1 2100 KGM 13670 KGM HLD6023429 F ==
# == HLBU 2969384 22G1 2300 KGM 4620 KGM HLD6024098 F ==
# == UACU 3823165 22G1 2300 KGM 6100 KGM HLC0156506 F ==
# == HLBU 1749127 22G1 2250 KGM 4500 KGM HLC0158744 F ==
# == HLXU 2693267 22P3 2740 KGM 17250 KGM NS F ==
# == UACU 3396042 22G1 2320 KGM 29230 KGM HLD1906674 F ==
# == UACU 4110940 22G1 2300 KGM 26850 KGM 00057822 F ==
# == FCIU 6650180 22G1 2100 KGM 26650 KGM 00057821 F ==
# == GMCU 3062900 22T6 4000 KGM 23305 KGM 002245537 F ==
# == GMCU 3063110 22T6 4000 KGM 23268 KGM 002245587 F ==
# == GMCU 3067440 22T6 4000 KGM 23287 KGM 002245521 F ==
# == SEGU 8061125 22T6 4000 KGM 23448 KGM 002245581 F ==
# == SEGU 8150325 22T6 4000 KGM 23276 KGM 002296690 F ==
# == SIMU 2626335 22T6 4000 KGM 23274 KGM 002245577 F ==
# == GMCU 3051206 22T6 3700 KGM 23215 KGM 001927621 F ==
# == GMCU 3265131 22T6 4050 KGM 23559 KGM 001927687 F ==
# == GMCU 6060650 22T6 4000 KGM 23162 KGM 002408177 F ==
# == SIMU 2683042 22T6 4000 KGM 23298 KGM 001927670 F ==
# == FCIU 3675116 22G1 2220 KGM 27736 KGM HLG0217621 F ==
# == HLXU 1130090 22G1 2350 KGM 27996 KGM HLG0217622 F ==
# == FTAU 1187766 22G1 2100 KGM 23107 KGM HLD1906903 HLD1906922 F ==
# == GLDU 3868501 22G1 2230 KGM 23237 KGM HLD1906912 F ==
# == HLBU 3461124 22G1 2200 KGM 23207 KGM HLD1907701 F ==
# == HLXU 1172325 22G1 2350 KGM 23357 KGM HLD1906924 F ==
# == HLXU 3411500 22G1 2350 KGM 23348 KGM HLD1907709 F ==
# == TGBU 2252373 22G1 2120 KGM 23127 KGM HLD1906913 F ==
# == TGCU 2088670 22G1 2130 KGM 23137 KGM HLD1907735 F ==
# == UACU 3647528 22G1 2130 KGM 23085 KGM HLD1906908 F ==
# == UACU 4027650 22G1 2300 KGM 23307 KGM HLD1907719 F ==
# == ==
# == T O T A L : 54 ==
# == ==
# ====================================================================================================================================
# ====================================================================================================================================
# == ==
# == C O N T A I N E R S U M M A R Y ==
# == ==
# ====================================================================================================================================
# == ==
# == 40' CONTAINER UNIT TYPE TARE WEIGHT GROSS WEIGHT 1.SEAL-NO LAST SEAL-NO TEMPERATURE SETTING OUT OF GAUGE E/F ==
# == --------------------------------------------------------------------------------------------------------------------------- ==
# == HLBU 9325608 45R1 4560 KGM 31938 KGM KG484258 -18.0 C F ==
# == TRIU 8145976 45R1 4630 KGM 30130 KGM WKL013571 -20.0 C F ==
# == HLXU 8751782 45R1 4510 KGM 30510 KGM WKL013569 -20.0 C F ==
# == HLBU 9393304 45R1 4450 KGM 30450 KGM WKL013568 -20.0 C F ==
# == UACU 4777845 45R1 4440 KGM 33560 KGM HLG3269101 3269101 -18.0 C F ==
# == SZLU 9189639 45R1 4700 KGM 33820 KGM HLG2924499 HLG2924499 -18.0 C F ==
# == TRLU 1663129 45R1 4750 KGM 33400 KGM ABO69589 069589 -18.0 C F ==
# == HLXU 8786618 45R1 4420 KGM 30560 KGM ABM88595 HLD0334646 -18.0 C F ==
# == LNXU 8453451 45R1 4640 KGM 29680 KGM ABO77506 HLD0334447 -18.0 C F ==
# == CAAU 5502042 45G1 3700 KGM 20620 KGM HLG4009102 F ==
# == CXDU 1889547 45G1 3850 KGM 20640 KGM HLG4009104 F ==
# == FANU 1462632 45G1 3680 KGM 20500 KGM HLG4009108 F ==
# == FANU 1563561 45G1 3680 KGM 20480 KGM HLG4009203 F ==
# == FANU 1800806 45G1 3680 KGM 20460 KGM HLG4009201 F ==
# == FANU 1872200 45G1 3680 KGM 20540 KGM HLG4009101 HLG 400910 F ==
# == FANU 1945604 45G1 3680 KGM 20640 KGM HLG4009206 4009206 F ==
# == FANU 3134479 45G1 3680 KGM 20700 KGM HLG4009110 F ==
# == FCIU 8098594 45G1 3900 KGM 20760 KGM HLG1381896 F ==
# == FCIU 8797550 45G1 3900 KGM 20760 KGM HLG4009205 F ==
# == HLBU 2046221 45G1 3900 KGM 20800 KGM HLG4009202 F ==
# == HLBU 2179250 45G1 3900 KGM 20840 KGM HLG4009102 F ==
# == HLBU 2417810 45G1 3900 KGM 20780 KGM HLG1381895 F ==
# == HLBU 2902014 45G1 3900 KGM 20760 KGM HLG4009204 F ==
# == HLBU 3314057 45G1 3900 KGM 20760 KGM HLG4009106 F ==
# == HLBU 3341601 45G1 3900 KGM 20780 KGM HLG4009105 F ==
# == TCLU 9551471 45G1 3840 KGM 20620 KGM HLG4009107 F ==
# == TGBU 6057230 45G1 3700 KGM 20460 KGM HLG4009103 F ==
# == HLBU 9482037 45R1 4550 KGM 33540 KGM HLG3317188 HLG3317188 -18.0 C F ==
# == NIDU 6501103 45R1 4420 KGM 33490 KGM HLG3257850 3257850 -18.0 C F ==
# == TCLU 1185592 45R1 4600 KGM 33720 KGM HLG3320886 HLG3320886 -18.0 C F ==
# == SEGU 9092394 45R1 4650 KGM 33770 KGM HLG3320854 HLG3320854 -18.0 C F ==
# == SEGU 9114560 45R1 4650 KGM 33770 KGM HLG3317193 3317193 -18.0 C F ==
# == HLXU 5635069 42U1 4050 KGM 16000 KGM MDXD 04855 MDXD 04855 F ==
# == HLXU 5637858 42U1 4050 KGM 19900 KGM 0483474 F ==
# == TCLU 7113558 42U1 3850 KGM 22300 KGM MDXD 04833 MDXD 04833 F ==
# == TRIU 0531972 42U1 3750 KGM 11900 KGM 0485738 F ==
# == UACU 4420729 42U1 4080 KGM 10800 KGM MDXD048348 MDXD048348 F ==
# == HLXU 8707985 45R1 4450 KGM 31330 KGM 1212694 IW2204/041 -20.0 C F ==
# == BMOU 4950894 45G1 3860 KGM 26540 KGM C11242 F ==
# == CAIU 4298641 45G1 3750 KGM 26500 KGM C11250 11250 F ==
# == HLBU 1713206 45G1 3900 KGM 26560 KGM C11260 F ==
# == TXGU 7135407 45G1 3700 KGM 26320 KGM C11245 F ==
# == UACU 5191442 45G1 3970 KGM 26580 KGM C11241 F ==
# == UACU 5792525 45G1 3800 KGM 26480 KGM C11243 F ==
# == BMOU 6636080 45G1 3850 KGM 24208 KGM 2288475 F ==
# == FANU 3068783 45G1 3680 KGM 25438 KGM S975229 F ==
# == FBLU 0106989 45G1 3700 KGM 24170 KGM S990368 990368 F ==
# == FDCU 0135557 45G1 3700 KGM 24144 KGM 2286017 F ==
# == HLBU 2784518 45G1 3900 KGM 24306 KGM S993982 F ==
# == HLBU 2905245 45G1 3900 KGM 27118 KGM 1125151 F ==
# == TCLU 1026076 45R1 4500 KGM 30600 KGM C16207 00508/IW24 -20.0 C F ==
# == SEGU 9087839 45R1 4520 KGM 30600 KGM 000366/IW2 000366/IW2 -20.0 C F ==
# == FCIU 9107221 45G1 3830 KGM 6086 KGM PCC0370683 F ==
# == FSCU 8254905 45G1 3830 KGM 6086 KGM PCC038507 F ==
# == HLXU 8218958 45G1 3950 KGM 6206 KGM PCC0375068 F ==
# == HLXU 8449941 45G1 3900 KGM 9392 KGM PCC0382665 F ==
# == TCNU 8078248 45G1 3950 KGM 6206 KGM PCC0377484 PCC0377484 F ==
# == TGHU 6237002 45G1 3890 KGM 6146 KGM PCC0369404 F ==
# == UACU 5844887 45G1 3800 KGM 6056 KGM PCC0385011 F ==
# == BMOU 4232114 45G1 3860 KGM 6060 KGM PCC0385131 0385131 F ==
# == FCGU 1989527 45G1 3820 KGM 6020 KGM PCC0382689 PCC0382689 F ==
# == FSCU 7175118 45G1 3700 KGM 5900 KGM PCC0382667 F ==
# == TGCU 5168608 45G1 3700 KGM 5900 KGM PCC0367966 F ==
# == BEAU 4180891 45G1 3850 KGM 26870 KGM 0654749 S989332 F ==
# == FCIU 9165249 45G1 3830 KGM 27100 KGM 0756953 S989333 F ==
# == HLBU 2169340 45G1 3900 KGM 27322 KGM 0662300 S989251 F ==
# == HLBU 2826763 45G1 3910 KGM 26233 KGM T361962 S989334 F ==
# == FANU 1841507 45G1 3680 KGM 26688 KGM AE458445 F ==
# == FDCU 0343890 45G1 3700 KGM 26399 KGM S990367 F ==
# == FFAU 1188955 45G1 3700 KGM 25446 KGM 1096431 F ==
# == HLBU 3174757 45G1 3900 KGM 27360 KGM S999406 F ==
# == HLXU 8550448 45G1 3900 KGM 26685 KGM 0193754 F ==
# == SEGU 5670386 45G1 3830 KGM 26814 KGM 0193834 F ==
# == SEGU 5799413 45G1 3830 KGM 26486 KGM S993983 F ==
# == TEMU 7082222 45G1 3890 KGM 27211 KGM AE485384 F ==
# == TEMU 7528274 45G1 3910 KGM 27142 KGM S990885 F ==
# == TGBU 6045570 45G1 3700 KGM 26810 KGM S990438 S 990438 F ==
# == UACU 5795308 45G1 3800 KGM 27026 KGM S994119 F ==
# == UACU 6042295 45G1 3800 KGM 26859 KGM 0193910 F ==
# == UAEU 1252763 45R1 4585 KGM 30600 KGM 1133956 000503/IW2 -20.0 C F ==
# == HLBU 9384787 45R1 4450 KGM 33290 KGM PP1014 HLG2504713 -20.0 C F ==
# == HLBU 9524472 45R1 4560 KGM 33490 KGM HLG2494745 HLG2494745 -20.0 C F ==
# == DFSU 6633680 45G1 3800 KGM 9530 KGM P4854163 F ==
# == FANU 3086895 45G1 3680 KGM 7540 KGM MISSING SE CTSO 00627 F ==
# == HLBU 2061416 45G1 3900 KGM 23600 KGM HLB1443978 1443978 F ==
# == FANU 1569111 45G1 3680 KGM 10720 KGM HLC0162033 F ==
# == UASU 1024201 45G1 3800 KGM 13910 KGM HLD6024317 HLD6024317 F ==
# == FANU 3102445 45G1 3680 KGM 9550 KGM HLC0156524 F ==
# == TLLU 5341109 45G1 3700 KGM 9600 KGM HLC0158854 F ==
# == TLLU 5407377 45G1 3700 KGM 7350 KGM HLC0156543 F ==
# == TCNU 1948881 45G1 3700 KGM 18379 KGM 015101 E015101 F ==
# == GCXU 5945260 45G1 3700 KGM 8370 KGM EUR111111 F ==
# == HLBU 3251690 45G1 3900 KGM 8930 KGM EUR222222 222222 F ==
# == CXRU 1286466 45R1 4560 KGM 33880 KGM HLG2607737 HLG2607737 -20.0 C F ==
# == GESU 9311564 45R1 4540 KGM 33860 KGM HLG2607707 HLG2607707 -20.0 C F ==
# == GESU 9584384 45R1 4600 KGM 33670 KGM HLG2607731 2607731 -20.0 C F ==
# == HLBU 9066111 45R1 4550 KGM 33850 KGM HLG2607709 HLG2607709 -20.0 C F ==
# == HLXU 8791569 45R1 4420 KGM 33650 KGM HLG2607727 2607727 -20.0 C F ==
# == NIDU 6501572 45R1 4420 KGM 33990 KGM HLG2607708 HLG2607708 -20.0 C F ==
# == SEGU 9101264 45R1 4650 KGM 34000 KGM HLG2607734 HLG2607734 -20.0 C F ==
# == SEGU 9378120 45R1 4570 KGM 33760 KGM HLG2607735 HLG2607735 -20.0 C F ==
# == TTNU 8490387 45R1 4700 KGM 33830 KGM HLG2607729 HLG2607729 -20.0 C F ==
# == UACU 4742495 45R1 4560 KGM 33830 KGM HLG2607704 HLG2607704 -20.0 C F ==
# == CPSU 5107925 45R1 4660 KGM 33710 KGM HLG2607697 HLG2607697 -20.0 C F ==
# == HLBU 9042378 45R1 4570 KGM 33810 KGM HLG2607609 HLG2607609 -20.0 C F ==
# == HLBU 9168725 45R1 4600 KGM 33780 KGM HLG2607619 2607619 -20.0 C F ==
# == HLBU 9232233 45R1 4410 KGM 33630 KGM HLG2607612 HLG2607612 -20.0 C F ==
# == HLXU 8726584 45R1 4480 KGM 33850 KGM HLG2607636 HLG2607636 -20.0 C F ==
# == HLXU 8763802 45R1 4420 KGM 33660 KGM HLG2607615 2607615 -20.0 C F ==
# == TCLU 1026693 45R1 4500 KGM 33800 KGM HLG2607698 HLG2607698 -20.0 C F ==
# == TRLU 1716867 45R1 4640 KGM 33460 KGM HLG2607613 HLG2607613 -20.0 C F ==
# == UACU 4748641 45R1 4520 KGM 33860 KGM HLG2607695 HLG2607695 -20.0 C F ==
# == UACU 4793147 45R1 4585 KGM 33950 KGM HLG2607608 HLG2607608 -20.0 C F ==
# == UACU 4750340 45R1 4520 KGM 32720 KGM 019858 -23.0 C F ==
# == FANU 1313705 45G1 3680 KGM 7500 KGM 0411348 F ==
# == BEAU 4460911 45G1 3700 KGM 11700 KGM 0072100 F ==
# == FCIU 7443063 45G1 3700 KGM 9200 KGM 4761412 F ==
# == TCNU 9875499 45G1 3840 KGM 5500 KGM . 0411384 F ==
# == HLBU 2869209 45G1 3900 KGM 9000 KGM 00821426 821426 F ==
# == HLBU 1419064 45G1 3950 KGM 8500 KGM 7944047 F ==
# == FANU 1050717 45G1 3700 KGM 11700 KGM 0361465 HLG4002385 F ==
# == HLXU 8400880 45G1 3900 KGM 10400 KGM 0072107 72107 F ==
# == TCNU 1787468 45G1 3700 KGM 10700 KGM 0001620 F ==
# == TCKU 6060517 45G1 3730 KGM 7000 KGM 0072120 F ==
# == HLBU 9205876 45R1 4350 KGM 32805 KGM HLD0523739 -20.0 C F ==
# == HLXU 8778227 45R1 4420 KGM 31695 KGM HLG3893601 HLG3893601 -18.0 C F ==
# == TEMU 9038110 45R1 4520 KGM 30956 KGM HLG3893548 -18.0 C F ==
# == SEGU 6900457 45G1 3700 KGM 31832 KGM HLG3878323 F ==
# == HLBU 9171945 45R1 4560 KGM 31479 KGM ADAG-HL112 ADAG-HL112 -20.0 C F ==
# == HLBU 9493767 45R1 4560 KGM 31479 KGM ADAG-HL112 112472 -20.0 C F ==
# == UACU 4736640 45R1 4600 KGM 30954 KGM ADAG-HL112 ADAG-HL112 -20.0 C F ==
# == TEMU 9039267 45R1 4520 KGM 32739 KGM HLG2163452 2163452 -18.0 C F ==
# == HLXU 8384959 45G1 3900 KGM 29436 KGM HLG2156426 F ==
# == CAIU 4816102 45G1 3700 KGM 29620 KGM HLG2156369 F ==
# == GCXU 5175745 45G1 3700 KGM 29236 KGM HLG2154296 F ==
# == TCNU 8348683 45G1 3840 KGM 29376 KGM HLG5018965 F ==
# == HLBU 3407329 45G1 3900 KGM 29512 KGM HLG2156284 0002994 F ==
# == HLBU 9786472 45R1 4450 KGM 33189 KGM HLG2164482 -18.0 C F ==
# == MTSU 9670940 45G1 3700 KGM 29236 KGM HLG2156759 F ==
# == FANU 3186071 45G1 3680 KGM 29600 KGM HLG2156851 F ==
# == UACU 6047759 45G1 3800 KGM 29720 KGM HLG2156979 2156979 F ==
# == BMOU 9247930 45R1 4420 KGM 31121 KGM HLG2163444 HLG2163444 -18.0 C F ==
# == TCNU 1833809 45G1 3700 KGM 12200 KGM 9708754 F ==
# == HLXU 8078136 45G1 3950 KGM 11950 KGM 652400 F ==
# == HLBU 1838585 45G1 3900 KGM 11400 KGM 9708775 F ==
# == BMOU 5829552 45G1 3850 KGM 29665 KGM HLD1303285 HLD1303285 F ==
# == CAIU 8032346 45G1 3870 KGM 29868 KGM HLD1303336 HLD1303336 F ==
# == HLBU 3193649 45G1 3900 KGM 29000 KGM HLD1308078 HLD1308078 F ==
# == HLXU 8110177 45G1 3950 KGM 29667 KGM HLD1302695 HLD1302695 F ==
# == TCLU 6419013 45G1 3840 KGM 29502 KGM HLD1305184 HLD1305184 F ==
# == GLDU 7425142 45G1 3900 KGM 29524 KGM HLD1305194 F ==
# == HLBU 1862431 45G1 3900 KGM 29205 KGM HLD1301594 1301594 F ==
# == TCLU 5277064 45G1 3840 KGM 29593 KGM HLD1304059 HLD1304059 F ==
# == UACU 5355382 45G1 3970 KGM 7495 KGM HLD1303377 HLD1303377 F ==
# == BEAU 4998888 45G1 3700 KGM 29800 KGM HLD1303368 F ==
# == SEGU 5708347 45G1 3830 KGM 29930 KGM HLD1303356 1303356 F ==
# == ==
# == T O T A L : 156 ==
# == ==
# ====================================================================================================================================
# OMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 266 / 266
# ABIDJAN VESSEL: MARTHA A DATE: 2023-02-02
# MASTER: DP-VOYAGE-NO: 297282 TIME: 13:32
# FLAG: TURKIYE SCHED.VOY-NO: 2302S
# OFF.REG-NO: 111054 EXT-VOYAGE-NO:
# -----------------------------------------------------------------------------------------------------------------------------------
# M A N I F E S T P O R T S U M M A R Y: ABIDJAN
# TOTAL DOCUMENTS: 163 TOTAL PACKAGES: 283506 TOTAL GROSS WEIGHT: 7124854 KGM TOTAL VOLUME: 145783 MTQ
# TOTAL FREIGHT TONS: 145783 FTN
# TWO HUNDRED AND EIGHTY-THREE THOUSAND AND FIVE HUNDRED AND SIX PACKAGES ONLY
# TOTAL FULL 20' : 128
# TOTAL FULL 40' : 256
# TOTAL EMPTY 20' : 0
# TOTAL EMPTY 40' : 0
# -----------------------------------------------------------------------------------------------------------------------------------

# %%
#pip install streamlit

# %%
import pdfplumber
import pandas as pd

file = 'C:\\Users\\APELI\\Desktop\\PDF_EXTRACT\\PDF\\TEST\\(1-40).pdf'

# Ouvrir le PDF et extraire le texte
with pdfplumber.open(file) as pdf:
    text = ""
    for page in pdf.pages:
        text += page.extract_text()

# Découper le texte en lignes
lines = text.split('\n')

# Organiser le texte en colonnes (exemple)
column_data = {
    'Column1': [],
    'Column2': [],
    'Column3': [],
    'Column4': [],
}

current_column = None

for line in lines:
    # Identifier la colonne en fonction du contenu de la ligne
    if 'DOCUMENT MARKS & NUMBERS' in line:
        current_column = 'Column1'
    elif 'QUANTITY' in line:
        current_column = 'Column2'
    elif 'DESCRIPTION OF GOODS' in line:
        current_column = 'Column3'
    elif 'WEIGHT & VOLUME' in line:
        current_column = 'Column4'
    
    # Ajouter la ligne à la colonne correspondante
    if current_column:
        column_data[current_column].append(line)

# Créer un DataFrame pandas à partir des données organisées
df = pd.DataFrame(column_data)

# Afficher le DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 41
#      38         column_data[current_column].append(line)
#      40 # Créer un DataFrame pandas à partir des données organisées
# ---> 41 df = pd.DataFrame(column_data)
#      43 # Afficher le DataFrame
#      44 print(df)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %%
import pdfplumber
import pandas as pd

file = 'C:\\Users\\APELI\\Desktop\\PDF_EXTRACT\\PDF\\TEST\\(1-40).pdf'

# Ouvrir le PDF et extraire le texte
with pdfplumber.open(file) as pdf:
    text = ""
    for page in pdf.pages:
        text += page.extract_text()

# Découper le texte en lignes
lines = text.split('\n')

# Organiser le texte en colonnes
column_data = {
    'Column1': [],
    'Column2': [],
    'Column3': [],
    'Column4': [],
}

current_column = None

for line in lines:
    # Identifier la colonne en fonction du contenu de la ligne
    if 'DOCUMENT MARKS & NUMBERS' in line:
        current_column = 'Column1'
    elif 'QUANTITY' in line:
        current_column = 'Column2'
    elif 'DESCRIPTION OF GOODS' in line:
        current_column = 'Column3'
    elif 'WEIGHT & VOLUME' in line:
        current_column = 'Column4'
    
    # Ajouter la ligne à la colonne correspondante
    if current_column:
        column_data[current_column].append(line)

# Assurez-vous que toutes les colonnes ont la même longueur
min_length = min(len(column_data['Column1']), len(column_data['Column2']), len(column_data['Column3']), len(column_data['Column4']))


print(column_data)
# Créer un DataFrame pandas à partir des données organisées en vérifiant la longueur
#df = pd.DataFrame({
#    'Column1': column_data['Column1'][:min_length],
#    'Column2': column_data['Column2'][:min_length],
 #   'Column3': column_data['Column3'][:min_length],
 #   'Column4': column_data['Column4'][:min_length]
#})

# Afficher le DataFrame
#print(df)
# Out:
# {'Column1': ['DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME', '-----------(0001)------------------------------------------------------------------------------------------------------------------', 'HLCUANR221214610 SWB ONE 40\' X 8\' X 9\'6" REEFER CON SLAC', 'HL-REF: 30005413 2,085 CARTONS 27,395.000 KGM GROSS', '(001) 756 CARTONS', 'SHIPPER: FROZEN PORK NECKBONES 50.000 MTQ GROSS', 'NORWEST FOODS INTERNATIONAL LTD. NET WEIGHT: 12852.00 KG', '3 HAIG COURT, HAIG ROAD, GROSS WEIGHT: 13384.00 KG', 'KNUTSFORD, CHESHIRE,', 'WA16 8XZ, 875 CARTONS', 'UNITED KINGDOM FROZEN PORK FRONT FEET', '+44 (0) 1565 759 000 NET WEIGHT: 8750.00 KG', 'GROSS WEIGHT: 9282.00 KG', 'CONSIGNEE:', 'YASK-SERVICES 454 CARTONS', '13 BP 193 FROZEN PORK RIBLETS', 'ABIDJAN 13 NET WEIGHT: 4540.00 KG', "COTE D 'IVOIRE GROSS WEIGHT: 4729.00 KG", 'NOTIFY PARTY 1: TOTAL NET WEIGHT:', 'YASK-SERVICES 26142.00 KG', '13 BP 193', 'ABIDJAN 13 BSC NO. #CIIMP-207550', "COTE D 'IVOIRE HS-CODE : 02 06 49", 'PLACE OF RECEIPT (START):', 'BEANR; ANTWERP UACU 4787442 (45R1)', 'SEAL NO 1: BS0989161', 'PLACE OF DELIVERY (END): TARE WEIGHT: 4,585 KGM', 'CIABJ; ABIDJAN', 'FCL/FCL', 'BILL TOTALS 2,085 27,395.000 KGM GROSS', "50.000 MTQ GROSSOMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 2 / 266", 'ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02', 'MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32', 'FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12', 'OFF.REG-NO: 111054 EXT-VOYAGE-NO:', 'DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME', '-----------(0002)------------------------------------------------------------------------------------------------------------------', 'HLCUANR221245690 SWB ONE 20\' X 8\' X 8\'6" GENERAL PU SLAC', 'HL-REF: 35351895 3 DRUMS 666.000 KGM GROSS', '(001) CALCIUM 10%', 'SHIPPER: HS-CODE : 28 36 50 0.988 MTQ GROSS', 'CHEMICAL PARTNERS AFRICA NV', 'KAPELSESTEENWEG 119 3 DRUMS 657.000 KGM GROSS', '2180 EKEREN (002) ZIRCONIUM 12%', 'BELGIUM HS-CODE : 28 25 60 0.975 MTQ GROSS', 'CONSIGNEE: 2 DRUMS 436.000 KGM GROSS', 'C2CI (003) COBALT 10%', "COULEURS DE COTE D'IVOIRE IMO-CLASS: 9 0.648 MTQ GROSS", '26 BP 1377 UN-NUMBER: 3082', "ABIDJAN 26 - COTE D'IVOIRE FLASHPOINT: 61.0 C", 'PACKING GROUP: 3', 'NOTIFY PARTY 1: PROPER SHIPPING NAME:', 'C2CI ENVIRONMENTALLY HAZARDOUS', "COULEURS DE COTE D'IVOIRE SUBSTANCE, LIQUID, N.O.S.", '26 BP 1377', "ABIDJAN 26 - COTE D'IVOIRE HS-CODE : 71 17 11", 'PLACE OF RECEIPT (START): 4 DRUMS 795.000 KGM GROSS', 'BEANR; ANTWERP (004) METHYL ETHYL KETOXIME (MEKO)', 'HS-CODE : 29 14 19 1.180 MTQ GROSS', 'PLACE OF DELIVERY (END):', 'CIABJ; ABIDJAN 100 BAGS 2,550.000 KGM GROSS', '(005) SODIUM HEXAMETAPHOSPHATE', 'HS-CODE : 28 35 29 3.783 MTQ GROSS', '84 BAGS 2,260.000 KGM GROSS', '(006) ZINC PHOSPHATE', 'IMO-CLASS: 9 3.353 MTQ GROSS', 'UN-NUMBER: 3077', 'PACKING GROUP: 3', 'PROPER SHIPPING NAME:', 'ENVIRONMENTALLY HAZARDOUS', 'SUBSTANCE, SOLID, NOS', 'HS-CODE : 28 35 29', '12 BAGS 307.000 KGM GROSS', '(007) YELLOW MIDDLE CHROME 5080', 'IMO-CLASS: 9 0.455 MTQ GROSS', 'UN-NUMBER: 3077', 'PACKING GROUP: 3', 'PROPER SHIPPING NAME:', 'ENVIRONMENTALLY HAZARDOUS', 'SUBSTANCE, SOLID, NOS', 'HS-CODE : 32 04 17', "THIS B/L CONTINUED ON NEXT PAGEOMA CTE D'IVOIRE SARL C U S T O M S M A N I F E S T I M P O R T (CARGO DECLARATION) PAGE: 3 / 266", 'ABIDJAN VESSEL: MARTHA A POL: ANTWERP LOADING: 2023-01-15 06:30 DATE: 2023-02-02', 'MASTER: DP-VOYAGE-NO: 297282 POL-DEP: 2023-01-16 12:12 TIME: 13:32', 'FLAG: TURKIYE SCHED.VOY-NO: 2302S POD: ABIDJAN POD-ARR: 2023-02-01 15:12', 'OFF.REG-NO: 111054 EXT-VOYAGE-NO:', 'DOCUMENT MARKS & NUMBERS QUANTITY DESCRIPTION OF GOODS WEIGHT & VOLUME', '-----------(CONTINUED FROM PREVIOUS PAGE)-------------------------------------------------------------------------------------------', 'HLCUANR221245690 (CONT) 20 BAGS 512.000 KGM GROSS', '(008) YELLOW CHROME LEM ...

# %%
import pdfplumber
import pytesseract
from pdf2image import convert_from_path
import re
import cv2
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
import os
import glob

def extract_from_page(page_number, page):
    texte = page.extract_text()
    if texte == "":
        # Convertir l'image en niveaux de gris
        gray = cv2.cvtColor(np.array(images[page_number]), cv2.COLOR_RGB2GRAY)
        
        # Apply OCR to get the OSD (Orientation and Script Detection) information
        data = pytesseract.image_to_osd(gray)
        # Extract the rotation angle from the OSD data
        lines = data.splitlines()
        rotation_line = next((line for line in lines if line.startswith('Rotate:')), None)
        rotation_angle = int(rotation_line.split(':')[1])
        # Rotate the image to correct the text rotation
        if rotation_angle != 0:
            if rotation_angle == 90:
                gray = cv2.rotate(gray, cv2.ROTATE_90_CLOCKWISE)
            elif rotation_angle == 180:
                gray = cv2.rotate(gray, cv2.ROTATE_180)
            elif rotation_angle == 270:
                gray = cv2.rotate(gray, cv2.ROTATE_90_COUNTERCLOCKWISE)
                
        # Appliquer des techniques de prétraitement d'image pour nettoyer les traces de stylos
        # Par exemple, appliquer un filtre de flou pour réduire le bruit
        blurred = cv2.GaussianBlur(gray, (5, 5), 0)
        # Appliquer une segmentation en seuillage adaptatif pour isoler le texte
        _, threshold = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
        
        # Effectuer OCR sur l'image traitée
        texte = pytesseract.image_to_string(threshold, lang='eng', config='--psm 4')
        
    lines = texte.split("\n")
    aev_words = []
    voyage_words = []
    vessel_words = []
    flag_words = []
    loading_words = []
    discharge_words = []
    first_line_below_bl_total = []
    second_line_below_bl_total = []
    sh_words = []
    cn_words = []
    no_words = []
    regex_matched_text = []
    #next_lines = []
    
    #regex_pattern = r"(\d{2}X\s*\d{2}\'*\s*[A-Z]+\s*[A-Z]{3})(?:.*\n){3}"
    
    for i, line in enumerate(lines):
        ########### Infos sur marchandises
        patern=r'\b(\d+\s*X\s*\d+\'*[A-Za-z]+\s*\w+\s*\w+\s*\w+\s*\w+)\b|\d+\s*[A-Za-z]+\s*\d+\''
        #regex_match = re.findall(r"(\d{2}X\s*\d{2}\'*\s*[A-Z]+\s*[A-Z]{3})", line)
        regex_match = re.findall(patern, line)
        regex_matched_text.extend(regex_match)
        if regex_match:
            regex_matched_text.extend(regex_match)
            
            # Concaténer les trois lignes suivantes dans une seule chaîne de caractères
            next_lines = lines[i+1:i+6]
            concatenated_lines = ' '.join(next_lines)
            
            regex_matched_text.append(concatenated_lines)
        #if regex_match:
            #regex_matched_tex = regex_match.group(1)
            #regex_matched_text.append(" ".join(regex_matched_tex.groups()))
        ####pattern = r'^[A-Z]{1,4}\d{6,}\s*[A-Z]{1}|^[A-Z]{1,4}\d{6,}'
        words = re.findall(r'^[A-Z]{1,4}\d{6,}\w*', line)###Recupere les BL
        aev_words.extend(words)
        
        voyage_match = re.search(r'VOYAGE:\s*(\w+)', line)
        if voyage_match:
            voyage_word = voyage_match.group(1)
            voyage_words.append(voyage_word)
        
        vessel_match = re.search(r'VESSEL:\s*(\w+)', line)
        if vessel_match:
            vessel_word = vessel_match.group(1)
            vessel_words.append(vessel_word)
        
        flag_match = re.search(r'FLAG:\s*(\w+)', line)
        if flag_match:
            flag_word = flag_match.group(1)
            flag_words.append(flag_word)
        
        loading_match = re.search(r'Actual Port of Loading\s*(\w+)', line)
        if loading_match:
            loading_word = loading_match.group(1)
            loading_words.append(loading_word)
        
        discharge_match = re.search(r'Actual Port of Discharge\s*(\w+)', line)
        if discharge_match:
            discharge_word = discharge_match.group(1)
            discharge_words.append(discharge_word)
        
        sh_match = re.search(r'SH:\s*(\w+)\s*(\w+)\s*(\w+)\s*(\w+)', line)
        if sh_match:
            sh_words.append(" ".join(sh_match.groups()))
        
        cn_match = re.search(r'CN:\s*(\w+)\s*(\w+)\s*(\w+)\s*(\w+)', line)
        if cn_match:
            cn_words.append(" ".join(cn_match.groups()))
        
        no_match = re.search(r'^N:\s*(\w+)\s*(\w+)\s*(\w+)\s*(\w+)', line)
        if no_match:
            no_words.append(" ".join(no_match.groups()))
        
        if "ITEMS:" in line:
            first_line_below_bl_total.append(line)
        
        if "SPLITS:" in line:
            second_line_below_bl_total.append(line)
        
        ## Récupérer le format "12X40 ST STC" et les trois lignes suivantes
       # regex_match = re.search(r"(\d{2}X\s*\d{2}\'*\s*[A-Z]+\s*[A-Z]{3})(?:.*\n){3}", line)
        #if regex_match:
            #regex_matched_tex = regex_match.group(1)
            #regex_matched_text.append(" ".join(regex_matched_tex.groups()))
            # Récupérer les trois lignes suivantes
            #next_lines = lines[i+1:i+4]
    
    if not aev_words:
        aev_words.append("N/A")
    if not voyage_words:
        voyage_words.append("N/A")
    if not vessel_words:
        vessel_words.append("N/A")
    if not flag_words:
        flag_words.append("N/A")
    if not loading_words:
        loading_words.append("N/A")
    if not discharge_words:
        discharge_words.append("N/A")
    if not first_line_below_bl_total:
        first_line_below_bl_total.append("N/A")
    if not second_line_below_bl_total:
        second_line_below_bl_total.append("N/A")
    if not sh_words:
        sh_words.append("N/A")
    if not cn_words:
        cn_words.append("N/A")
    if not no_words:
        no_words.append("N/A")
    if not regex_matched_text:
        regex_matched_text.append("N/A")
    #if not next_lines:
        # next_lines.append("N/A")
    
    
    return (
        aev_words, voyage_words, vessel_words, flag_words, loading_words,
        discharge_words, first_line_below_bl_total, second_line_below_bl_total,
        sh_words, cn_words, no_words, regex_matched_text
    )


# Chemin vers le dossier contenant les fichiers PDF
dossier_pdf = 'C:\\Users\\APELI\\Desktop\\PDF_EXTRACT\\PDF\\TEST'
# Chemin vers le dossier contenant les fichiers XML
dossier_xml ='C:\\Users\\APELI\\Desktop\\PDF_EXTRACT\\PDF'
# Chemin vers le dossier contenant les fichiers CSV
dossier_csv = 'C:\\Users\\APELI\\Desktop\\PDF_EXTRACT\\PDF'

# Rechercher tous les fichiers PDF dans le dossier
chemins_pdf = glob.glob(os.path.join(dossier_pdf, '*.pdf'))

# Parcourir chaque fichier PDF trouvé
for chemin_pdf in chemins_pdf:
    # Convertir les pages PDF en images en utilisant pdf2image
    images = convert_from_path(chemin_pdf, dpi=600)
    # Ouvrir le fichier PDF avec PDFplumber
    with pdfplumber.open(chemin_pdf) as pdf:
        aev_words_list = []
        voyage_words_list = []
        vessel_words_list = []
        flag_words_list = []
        loading_words_list = []
        discharge_words_list = []
        first_line_below_bl_total_list = []
        second_line_below_bl_total_list = []
        sh_words_list = []
        cn_words_list = []
        no_words_list = []
        regex_matched_text_list = []
        #next_lines_list = []
        
        
        for page_number, page in enumerate(pdf.pages):
            page_aev_words, page_voyage_words, page_vessel_words, page_flag_words, page_loading_words, page_discharge_words, page_first_line_below_bl_total, page_second_line_below_bl_total, page_sh_words, page_cn_words, page_no_words, page_regex_matched_text = extract_from_page(page_number, page)
            aev_words_list.extend(page_aev_words)
            voyage_words_list.extend(page_voyage_words)
            vessel_words_list.extend(page_vessel_words)
            flag_words_list.extend(page_flag_words)
            loading_words_list.extend(page_loading_words)
            discharge_words_list.extend(page_discharge_words)
            first_line_below_bl_total_list.extend(page_first_line_below_bl_total)
            second_line_below_bl_total_list.extend(page_second_line_below_bl_total)
            sh_words_list.extend(page_sh_words)
            cn_words_list.extend(page_cn_words)
            no_words_list.extend(page_no_words)
            regex_matched_text_list.extend(page_regex_matched_text)
            #next_lines_list.extend(page_next_lines)
#######################################################################################################################################################            
            # Vérifier la longueur des listes
            list_lengths = [len(aev_words_list), len(voyage_words_list), len(vessel_words_list), len(flag_words_list), len(loading_words_list), len(discharge_words_list), len(first_line_below_bl_total_list), len(second_line_below_bl_total_list), len(sh_words_list), len(cn_words_list), len(no_words_list), len(regex_matched_text_list)]
            max_length = max(list_lengths)
            
            # Remplir les listes manquantes avec "N/A" pour atteindre la même longueur
            aev_words_list += ["N/A"] * (max_length - len(aev_words_list))
            voyage_words_list += ["N/A"] * (max_length - len(voyage_words_list))
            vessel_words_list += ["N/A"] * (max_length - len(vessel_words_list))
            flag_words_list += ["N/A"] * (max_length - len(flag_words_list))
            loading_words_list += ["N/A"] * (max_length - len(loading_words_list))
            discharge_words_list += ["N/A"] * (max_length - len(discharge_words_list))
            first_line_below_bl_total_list += ["N/A"] * (max_length - len(first_line_below_bl_total_list))
            second_line_below_bl_total_list += ["N/A"] * (max_length - len(second_line_below_bl_total_list))
            sh_words_list += ["N/A"] * (max_length - len(sh_words_list))
            cn_words_list += ["N/A"] * (max_length - len(cn_words_list))
            no_words_list += ["N/A"] * (max_length - len(no_words_list))
            regex_matched_text_list += ["N/A"] * (max_length - len(regex_matched_text_list))
            #next_lines_list += ["N/A"] * (max_length - len(next_lines_list))
            
        # Créer un DataFrame à partir des listes de mots AEV0188950, Voyage, Vessel, Flag et Actual Port of Loading
    df = pd.DataFrame({"Voyage": voyage_words_list, "BL": aev_words_list, "Vessel": vessel_words_list, "Flag": flag_words_list, "Actual_Port_of_Loading": loading_words_list, "Actual_Port_of_discharge": discharge_words_list, "Number_line1": first_line_below_bl_total_list, "Number_line2": second_line_below_bl_total_list, "Shipper": sh_words_list, "Consigner": cn_words_list, "Notifie": no_words_list, "Description" : regex_matched_text_list})
    # Diviser le champ "Nom Complet" en prénom, deuxième prénom, nom de famille et suffixe
    df[['ITEMS', 'Type_contener', 'PACKS', 'Nbre_colis', 'WGT', 'Poids_march','Unite_poids']] = df['Number_line1'].str.split(" ", 6, expand=True)
    df[['SPLITS', 'Nbre_contener', 'IN_PACKS', 'Nbre_INPACKS', 'VOL', 'Volum_march','Unite_volum']] = df['Number_line2'].str.split(" ", 6, expand=True)
    # Supprimer les champs "Prénom" et "Nom de Famille"
    champs_a_supprimer = ["ITEMS", "PACKS", "WGT", "Number_line1", "SPLITS", "IN_PACKS", "Nbre_INPACKS", "VOL", "Number_line2"]
    df = df.drop(columns=champs_a_supprimer)
    # Extraire le nom du fichier
    Id_fichier = os.path.basename(chemin_pdf)
    # Ajouter la colonne "Nom du Fichier" avec la valeur du nom du fichier
    df['Nom_du_Fichier'] = Id_fichier
############################################################################################
    last_bl_index = df['BL'].last_valid_index()
# Parcourir la colonne "BL" et remplacer chaque "N/A" par la dernière valeur non nulle
    for i, value in enumerate(df['BL']):
        if value == "N/A":
            df.at[i, 'BL'] = df.at[last_bl_index, 'BL']
        else:
            last_bl_index = i  # Mettre à jour l'index de la dernière valeur non nulle
############################################################################################
############################################################################################
   
    # chaque occurrence de "N/A" sera remplacée par la dernière valeur non nulle trouvée avant celle-ci.
    df = df.groupby("BL").agg({
        "Voyage": "first", 
        "Vessel": "first", 
        "Flag": "first",  
        "Actual_Port_of_Loading": "first", 
        "Actual_Port_of_discharge": "first", 
        "Shipper": "first",  
        "Consigner": "first", 
        "Notifie": "first", 
        "Description":lambda x: list(set(x)),  # Prendre les valeurs uniques de "Description" pour chaque groupe "BL"  
        "Type_contener": "last", 
        "Nbre_colis": "last", 
        "Poids_march": "last",  
        "Unite_poids": "last", 
        "Nbre_contener": "last",   
        "Volum_march": "last",
        "Unite_volum": "last",
        "Nom_du_Fichier": "last"
    }).reset_index()
    
    # Convertir les listes en chaînes de caractères dans le DataFrame
    #df['Description'] = ' '.join(map(str, df['Description']))
    df['Description'] = df['Description'].apply(lambda liste: ' '.join(map(str, liste)))
    
    ######################################################################################################
    root = ET.Element('manifest')
    
    # Conversion du dataframe en XML
    for _, row in df.iterrows():
        result = ET.SubElement(root, 'Result')
        
        ET.SubElement(result, 'Voyage').text = row['Voyage']
        ET.SubElement(result, 'BL').text = row['BL']
        ET.SubElement(result, 'Vessel').text = row['Vessel']
        ET.SubElement(result, 'Flag').text = row['Flag']
        ET.SubElement(result, 'Actual_Port_of_Loading').text = row['Actual_Port_of_Loading']
        ET.SubElement(result, 'Actual_Port_of_discharge').text = row['Actual_Port_of_discharge']
        ET.SubElement(result, 'Nbre_colis').text = row['Nbre_colis']
        ET.SubElement(result, 'Poids_march').text = row['Poids_march']
        ET.SubElement(result, 'Unite_poids').text = row['Unite_poids']
        ET.SubElement(result, 'Nbre_contener').text = row['Nbre_contener']
        ET.SubElement(result, 'Type_contener').text = row['Type_contener']
        ET.SubElement(result, 'Volum_march').text = row['Volum_march']
        ET.SubElement(result, 'Unite_volum').text = row['Unite_volum']
        ET.SubElement(result, 'Shipper').text = row['Shipper']
        ET.SubElement(result, 'Consigner').text = row['Consigner']
        ET.SubElement(result, 'Notifie').text = row['Notifie']
        ET.SubElement(result, 'Description').text = row['Description']
        
    # On peut ajouter d'autres éléments en fonction de la structure de votre dataframe
    
    # Enregistrer le XML dans un fichier avec un nom basé sur le fichier PDF
    nom_fichier_xml = os.path.splitext(os.path.basename(chemin_pdf))[0] + '.xml'
    chemin_fichier_xml = os.path.join(dossier_xml, nom_fichier_xml)
    # Création de l'arbre XML
    xml_tree = ET.ElementTree(root)
    # Enregistrement du XML dans un fichier
    xml_tree.write(chemin_fichier_xml, encoding='utf-8', xml_declaration=True)
    
    
    # Enregistrer le DataFrame en tant que fichier CSV avec un nom basé sur le fichier PDF
    nom_fichier_csv = os.path.splitext(os.path.basename(chemin_pdf))[0] + '.csv'
    chemin_fichier_csv = os.path.join(dossier_csv, nom_fichier_csv)
    df.to_csv(chemin_fichier_csv, index=False)
# Out:
# C:\Users\APELI\AppData\Local\Temp\ipykernel_14632\3230021834.py:235: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['ITEMS', 'Type_contener', 'PACKS', 'Nbre_colis', 'WGT', 'Poids_march','Unite_poids']] = df['Number_line1'].str.split(" ", 6, expand=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 235
#     233 df = pd.DataFrame({"Voyage": voyage_words_list, "BL": aev_words_list, "Vessel": vessel_words_list, "Flag": flag_words_list, "Actual_Port_of_Loading": loading_words_list, "Actual_Port_of_discharge": discharge_words_list, "Number_line1": first_line_below_bl_total_list, "Number_line2": second_line_below_bl_total_list, "Shipper": sh_words_list, "Consigner": cn_words_list, "Notifie": no_words_list, "Description" : regex_matched_text_list})
#     234 # Diviser le champ "Nom Complet" en prénom, deuxième prénom, nom de famille et suffixe
# --> 235 df[['ITEMS', 'Type_contener', 'PACKS', 'Nbre_colis', 'WGT', 'Poids_march','Unite_poids']] = df['Number_line1'].str.split(" ", 6, expand=True)
#     236 df[['SPLITS', 'Nbre_contener', 'IN_PACKS', 'Nbre_INPACKS', 'VOL', 'Volum_march','Unite_volum']] = df['Number_line2'].str.split(" ", 6, expand=True)
#     237 # Supprimer les champs "Prénom" et "Nom de Famille"
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3968, in DataFrame.__setitem__(self, key, value)
#    3966     self._setitem_frame(key, value)
#    3967 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
#    3970     self._set_item_frame_value(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4010, in DataFrame._setitem_array(self, key, value)
#    4005 else:
#    4006     # Note: unlike self.iloc[:, indexer] = value, this will
#    4007     #  never try to overwrite values inplace
#    4009     if isinstance(value, DataFrame):
# -> 4010         check_key_length(self.columns, key, value)
#    4011         for k1, k2 in zip(key, value.columns):
#    4012             self[k1] = value[k2]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexers\utils.py:401, in check_key_length(columns, key, value)
#     399 if columns.is_unique:
#     400     if len(value.columns) != len(key):
# --> 401         raise ValueError("Columns must be same length as key")
#     402 else:
#     403     # Missing keys in columns are represented as -1
#     404     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key

# %%
# %pwd
# Out:
# 'C:\\Users\\APELI\\Desktop\\PDF_EXTRACT'

# %%
#conda install -c anaconda tk

# %%
########### CODE AVEC DES FONCTIONS
###streamlit run app.py

import streamlit as st
import pdfplumber
import pytesseract
from pdf2image import convert_from_path
import re
import cv2
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
import os
import glob

def extract_from_page(page_number, page):
    texte = page.extract_text()
    if texte == "":
        # Convertir l'image en niveaux de gris
        gray = cv2.cvtColor(np.array(images[page_number]), cv2.COLOR_RGB2GRAY)
        
        # Apply OCR to get the OSD (Orientation and Script Detection) information
        data = pytesseract.image_to_osd(gray)
        # Extract the rotation angle from the OSD data
        lines = data.splitlines()
        rotation_line = next((line for line in lines if line.startswith('Rotate:')), None)
        rotation_angle = int(rotation_line.split(':')[1])
        # Rotate the image to correct the text rotation
        if rotation_angle != 0:
            if rotation_angle == 90:
                gray = cv2.rotate(gray, cv2.ROTATE_90_CLOCKWISE)
            elif rotation_angle == 180:
                gray = cv2.rotate(gray, cv2.ROTATE_180)
            elif rotation_angle == 270:
                gray = cv2.rotate(gray, cv2.ROTATE_90_COUNTERCLOCKWISE)
                
        # Appliquer des techniques de prétraitement d'image pour nettoyer les traces de stylos
        # Par exemple, appliquer un filtre de flou pour réduire le bruit
        blurred = cv2.GaussianBlur(gray, (5, 5), 0)
        # Appliquer une segmentation en seuillage adaptatif pour isoler le texte
        _, threshold = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
        
        # Effectuer OCR sur l'image traitée
        texte = pytesseract.image_to_string(threshold, lang='eng', config='--psm 4')
        
    lines = texte.split("\n")
    aev_words = []
    voyage_words = []
    vessel_words = []
    flag_words = []
    loading_words = []
    discharge_words = []
    first_line_below_bl_total = []
    second_line_below_bl_total = []
    sh_words = []
    cn_words = []
    no_words = []
    regex_matched_text = []
    #next_lines = []
    
    #regex_pattern = r"(\d{2}X\s*\d{2}\'*\s*[A-Z]+\s*[A-Z]{3})(?:.*\n){3}"
    
    for i, line in enumerate(lines):
        ########### Infos sur marchandises
        patern=r'\b(\d+\s*X\s*\d+\'*[A-Za-z]+\s*\w+\s*\w+\s*\w+\s*\w+)\b|\d+\s*[A-Za-z]+\s*\d+\''
        #regex_match = re.findall(r"(\d{2}X\s*\d{2}\'*\s*[A-Z]+\s*[A-Z]{3})", line)
        regex_match = re.findall(patern, line)
        regex_matched_text.extend(regex_match)
        if regex_match:
            regex_matched_text.extend(regex_match)
            
            # Concaténer les trois lignes suivantes dans une seule chaîne de caractères
            next_lines = lines[i+1:i+6]
            concatenated_lines = ' '.join(next_lines)
            
            regex_matched_text.append(concatenated_lines)
        #if regex_match:
            #regex_matched_tex = regex_match.group(1)
            #regex_matched_text.append(" ".join(regex_matched_tex.groups()))
        ####pattern = r'^[A-Z]{1,4}\d{6,}\s*[A-Z]{1}|^[A-Z]{1,4}\d{6,}'
        words = re.findall(r'^[A-Z]{1,4}\d{6,}\w*', line)###Recupere les BL
        aev_words.extend(words)
        
        voyage_match = re.search(r'VOYAGE:\s*(\w+)', line)
        if voyage_match:
            voyage_word = voyage_match.group(1)
            voyage_words.append(voyage_word)
        
        vessel_match = re.search(r'VESSEL:\s*(\w+)', line)
        if vessel_match:
            vessel_word = vessel_match.group(1)
            vessel_words.append(vessel_word)
        
        flag_match = re.search(r'FLAG:\s*(\w+)', line)
        if flag_match:
            flag_word = flag_match.group(1)
            flag_words.append(flag_word)
        
        loading_match = re.search(r'Actual Port of Loading\s*(\w+)', line)
        if loading_match:
            loading_word = loading_match.group(1)
            loading_words.append(loading_word)
        
        discharge_match = re.search(r'Actual Port of Discharge\s*(\w+)', line)
        if discharge_match:
            discharge_word = discharge_match.group(1)
            discharge_words.append(discharge_word)
        
        sh_match = re.search(r'SH:\s*(\w+)\s*(\w+)\s*(\w+)\s*(\w+)', line)
        if sh_match:
            sh_words.append(" ".join(sh_match.groups()))
        
        cn_match = re.search(r'CN:\s*(\w+)\s*(\w+)\s*(\w+)\s*(\w+)', line)
        if cn_match:
            cn_words.append(" ".join(cn_match.groups()))
        
        no_match = re.search(r'^N:\s*(\w+)\s*(\w+)\s*(\w+)\s*(\w+)', line)
        if no_match:
            no_words.append(" ".join(no_match.groups()))
        
        if "ITEMS:" in line:
            first_line_below_bl_total.append(line)
        
        if "SPLITS:" in line:
            second_line_below_bl_total.append(line)
        
        ## Récupérer le format "12X40 ST STC" et les trois lignes suivantes
       # regex_match = re.search(r"(\d{2}X\s*\d{2}\'*\s*[A-Z]+\s*[A-Z]{3})(?:.*\n){3}", line)
        #if regex_match:
            #regex_matched_tex = regex_match.group(1)
            #regex_matched_text.append(" ".join(regex_matched_tex.groups()))
            # Récupérer les trois lignes suivantes
            #next_lines = lines[i+1:i+4]
    
    if not aev_words:
        aev_words.append("N/A")
    if not voyage_words:
        voyage_words.append("N/A")
    if not vessel_words:
        vessel_words.append("N/A")
    if not flag_words:
        flag_words.append("N/A")
    if not loading_words:
        loading_words.append("N/A")
    if not discharge_words:
        discharge_words.append("N/A")
    if not first_line_below_bl_total:
        first_line_below_bl_total.append("N/A")
    if not second_line_below_bl_total:
        second_line_below_bl_total.append("N/A")
    if not sh_words:
        sh_words.append("N/A")
    if not cn_words:
        cn_words.append("N/A")
    if not no_words:
        no_words.append("N/A")
    if not regex_matched_text:
        regex_matched_text.append("N/A")
    #if not next_lines:
        # next_lines.append("N/A")
    
    
    return (
        aev_words, voyage_words, vessel_words, flag_words, loading_words,
        discharge_words, first_line_below_bl_total, second_line_below_bl_total,
        sh_words, cn_words, no_words, regex_matched_text
    )


## Chemin vers le dossier contenant les fichiers PDF
#dossier_pdf = 'C:\\Users\\APELI\\Desktop\\PDF_EXTRACT\\PDF'
## Chemin vers le dossier contenant les fichiers XML
#dossier_xml ='C:\\Users\\APELI\\Desktop\\PDF_EXTRACT\\PDF'
## Chemin vers le dossier contenant les fichiers CSV
#dossier_csv = 'C:\\Users\\APELI\\Desktop\\PDF_EXTRACT\\PDF'


def extract_info_from_pdf(pdf_path):
# Rechercher tous les fichiers PDF dans le dossier
    chemins_pdf = glob.glob(os.path.join(pdf_path, '*.pdf'))
    extracted_data_list = []
    # Parcourir chaque fichier PDF trouvé
    for chemin_pdf in chemins_pdf:
        # Convertir les pages PDF en images en utilisant pdf2image
        images = convert_from_path(chemin_pdf, dpi=600)
        # Ouvrir le fichier PDF avec PDFplumber
        with pdfplumber.open(chemin_pdf) as pdf:
            aev_words_list = []
            voyage_words_list = []
            vessel_words_list = []
            flag_words_list = []
            loading_words_list = []
            discharge_words_list = []
            first_line_below_bl_total_list = []
            second_line_below_bl_total_list = []
            sh_words_list = []
            cn_words_list = []
            no_words_list = []
            regex_matched_text_list = []
            #next_lines_list = []
            
            
            for page_number, page in enumerate(pdf.pages):
                page_aev_words, page_voyage_words, page_vessel_words, page_flag_words, page_loading_words, page_discharge_words, page_first_line_below_bl_total, page_second_line_below_bl_total, page_sh_words, page_cn_words, page_no_words, page_regex_matched_text = extract_from_page(page_number, page)
                aev_words_list.extend(page_aev_words)
                voyage_words_list.extend(page_voyage_words)
                vessel_words_list.extend(page_vessel_words)
                flag_words_list.extend(page_flag_words)
                loading_words_list.extend(page_loading_words)
                discharge_words_list.extend(page_discharge_words)
                first_line_below_bl_total_list.extend(page_first_line_below_bl_total)
                second_line_below_bl_total_list.extend(page_second_line_below_bl_total)
                sh_words_list.extend(page_sh_words)
                cn_words_list.extend(page_cn_words)
                no_words_list.extend(page_no_words)
                regex_matched_text_list.extend(page_regex_matched_text)
                #next_lines_list.extend(page_next_lines)
    #######################################################################################################################################################            
                # Vérifier la longueur des listes
                list_lengths = [len(aev_words_list), len(voyage_words_list), len(vessel_words_list), len(flag_words_list), len(loading_words_list), len(discharge_words_list), len(first_line_below_bl_total_list), len(second_line_below_bl_total_list), len(sh_words_list), len(cn_words_list), len(no_words_list), len(regex_matched_text_list)]
                max_length = max(list_lengths)
                
                # Remplir les listes manquantes avec "N/A" pour atteindre la même longueur
                aev_words_list += ["N/A"] * (max_length - len(aev_words_list))
                voyage_words_list += ["N/A"] * (max_length - len(voyage_words_list))
                vessel_words_list += ["N/A"] * (max_length - len(vessel_words_list))
                flag_words_list += ["N/A"] * (max_length - len(flag_words_list))
                loading_words_list += ["N/A"] * (max_length - len(loading_words_list))
                discharge_words_list += ["N/A"] * (max_length - len(discharge_words_list))
                first_line_below_bl_total_list += ["N/A"] * (max_length - len(first_line_below_bl_total_list))
                second_line_below_bl_total_list += ["N/A"] * (max_length - len(second_line_below_bl_total_list))
                sh_words_list += ["N/A"] * (max_length - len(sh_words_list))
                cn_words_list += ["N/A"] * (max_length - len(cn_words_list))
                no_words_list += ["N/A"] * (max_length - len(no_words_list))
                regex_matched_text_list += ["N/A"] * (max_length - len(regex_matched_text_list))
                #next_lines_list += ["N/A"] * (max_length - len(next_lines_list))
                
            # Créer un DataFrame à partir des listes de mots AEV0188950, Voyage, Vessel, Flag et Actual Port of Loading
        df = pd.DataFrame({"Voyage": voyage_words_list, "BL": aev_words_list, "Vessel": vessel_words_list, "Flag": flag_words_list, "Actual_Port_of_Loading": loading_words_list, "Actual_Port_of_discharge": discharge_words_list, "Number_line1": first_line_below_bl_total_list, "Number_line2": second_line_below_bl_total_list, "Shipper": sh_words_list, "Consigner": cn_words_list, "Notifie": no_words_list, "Description" : regex_matched_text_list})
        # Diviser le champ "Nom Complet" en prénom, deuxième prénom, nom de famille et suffixe
        df[['ITEMS', 'Type_contener', 'PACKS', 'Nbre_colis', 'WGT', 'Poids_march','Unite_poids']] = df['Number_line1'].str.split(" ", 6, expand=True)
        df[['SPLITS', 'Nbre_contener', 'IN_PACKS', 'Nbre_INPACKS', 'VOL', 'Volum_march','Unite_volum']] = df['Number_line2'].str.split(" ", 6, expand=True)
        # Supprimer les champs "Prénom" et "Nom de Famille"
        champs_a_supprimer = ["ITEMS", "PACKS", "WGT", "Number_line1", "SPLITS", "IN_PACKS", "Nbre_INPACKS", "VOL", "Number_line2"]
        df = df.drop(columns=champs_a_supprimer)
        # Extraire le nom du fichier
        Id_fichier = os.path.basename(chemin_pdf)
        # Ajouter la colonne "Nom du Fichier" avec la valeur du nom du fichier
        df['Nom_du_Fichier'] = Id_fichier
    ############################################################################################
        last_bl_index = df['BL'].last_valid_index()
    # Parcourir la colonne "BL" et remplacer chaque "N/A" par la dernière valeur non nulle
        for i, value in enumerate(df['BL']):
            if value == "N/A":
                df.at[i, 'BL'] = df.at[last_bl_index, 'BL']
            else:
                last_bl_index = i  # Mettre à jour l'index de la dernière valeur non nulle
    ############################################################################################
    ############################################################################################
    
        # chaque occurrence de "N/A" sera remplacée par la dernière valeur non nulle trouvée avant celle-ci.
        df = df.groupby("BL").agg({
            "Voyage": "first", 
            "Vessel": "first", 
            "Flag": "first",  
            "Actual_Port_of_Loading": "first", 
            "Actual_Port_of_discharge": "first", 
            "Shipper": "first",  
            "Consigner": "first", 
            "Notifie": "first", 
            "Description":lambda x: list(set(x)),  # Prendre les valeurs uniques de "Description" pour chaque groupe "BL"  
            "Type_contener": "last", 
            "Nbre_colis": "last", 
            "Poids_march": "last",  
            "Unite_poids": "last", 
            "Nbre_contener": "last",   
            "Volum_march": "last",
            "Unite_volum": "last",
            "Nom_du_Fichier": "last"
        }).reset_index()
        
        # Convertir les listes en chaînes de caractères dans le DataFrame
        #df['Description'] = ' '.join(map(str, df['Description']))
        df['Description'] = df['Description'].apply(lambda liste: ' '.join(map(str, liste)))

        extracted_data_list.append(df)
    extracted_data = pd.concat(extracted_data_list, ignore_index=True)
    
    #csv_filename = "extracted_data.csv"
    #csv_path = os.path.join(pdf_path, csv_filename)
    #extracted_data.to_csv(csv_path, index=False)
    #return csv_path (return le chemin contenant un csv)
    return extracted_data

# %%
pwd
# Out:
# 'C:\\Users\\APELI\\Desktop\\PDF_EXTRACT'

# %%
dossier = 'C:\\Users\\APELI\\Desktop\\PDF_EXTRACT\\PDF\\TEST'
extract_info_from_pdf(dossier)
# Out:
# C:\Users\APELI\AppData\Local\Temp\ipykernel_14632\3564372188.py:241: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['ITEMS', 'Type_contener', 'PACKS', 'Nbre_colis', 'WGT', 'Poids_march','Unite_poids']] = df['Number_line1'].str.split(" ", 6, expand=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 dossier = 'C:\\Users\\APELI\\Desktop\\PDF_EXTRACT\\PDF\\TEST'
# ----> 2 extract_info_from_pdf(dossier)
#
# Cell In[2], line 241, in extract_info_from_pdf(pdf_path)
#     239 df = pd.DataFrame({"Voyage": voyage_words_list, "BL": aev_words_list, "Vessel": vessel_words_list, "Flag": flag_words_list, "Actual_Port_of_Loading": loading_words_list, "Actual_Port_of_discharge": discharge_words_list, "Number_line1": first_line_below_bl_total_list, "Number_line2": second_line_below_bl_total_list, "Shipper": sh_words_list, "Consigner": cn_words_list, "Notifie": no_words_list, "Description" : regex_matched_text_list})
#     240 # Diviser le champ "Nom Complet" en prénom, deuxième prénom, nom de famille et suffixe
# --> 241 df[['ITEMS', 'Type_contener', 'PACKS', 'Nbre_colis', 'WGT', 'Poids_march','Unite_poids']] = df['Number_line1'].str.split(" ", 6, expand=True)
#     242 df[['SPLITS', 'Nbre_contener', 'IN_PACKS', 'Nbre_INPACKS', 'VOL', 'Volum_march','Unite_volum']] = df['Number_line2'].str.split(" ", 6, expand=True)
#     243 # Supprimer les champs "Prénom" et "Nom de Famille"
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3968, in DataFrame.__setitem__(self, key, value)
#    3966     self._setitem_frame(key, value)
#    3967 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
#    3970     self._set_item_frame_value(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4010, in DataFrame._setitem_array(self, key, value)
#    4005 else:
#    4006     # Note: unlike self.iloc[:, indexer] = value, this will
#    4007     #  never try to overwrite values inplace
#    4009     if isinstance(value, DataFrame):
# -> 4010         check_key_length(self.columns, key, value)
#    4011         for k1, k2 in zip(key, value.columns):
#    4012             self[k1] = value[k2]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexers\utils.py:401, in check_key_length(columns, key, value)
#     399 if columns.is_unique:
#     400     if len(value.columns) != len(key):
# --> 401         raise ValueError("Columns must be same length as key")
#     402 else:
#     403     # Missing keys in columns are represented as -1
#     404     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key

# %%
dossier = 'C:\\Users\\APELI\\Desktop\\PDF_EXTRACT\\PDF'
extract_info_from_pdf(dossier)
# Out:
# C:\Users\APELI\AppData\Local\Temp\ipykernel_14632\3564372188.py:241: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['ITEMS', 'Type_contener', 'PACKS', 'Nbre_colis', 'WGT', 'Poids_march','Unite_poids']] = df['Number_line1'].str.split(" ", 6, expand=True)
# C:\Users\APELI\AppData\Local\Temp\ipykernel_14632\3564372188.py:242: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['SPLITS', 'Nbre_contener', 'IN_PACKS', 'Nbre_INPACKS', 'VOL', 'Volum_march','Unite_volum']] = df['Number_line2'].str.split(" ", 6, expand=True)
#              BL     Voyage Vessel   Flag Actual_Port_of_Loading  \
# 0   AEV0188827B  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 1    AEV0188950  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 2    AEV0189228  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 3    AEV0189229  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 4    AEV0189572  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 5    AEV0189588  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 6    AEV0189589  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 7    AEV0189626  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 8    AEV0189709  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 9    AEV0189791  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 10   AEV0189811  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 11   AEV0189900  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 12   AEV0189964  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 13   AEV0190131  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 14   AEV0190144  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 15   AEV0190152  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 16   AEV0190365  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 17   AEV0190369  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 18   AEV0190370  0WWE2E1MA    CMA  MALTA                ABIDJAN
# 19   AEV0190371  0WWE2E1MA    CMA  MALTA                ABIDJAN
#
#    Actual_Port_of_discharge                       Shipper  \
# 0                   ANTWERP       SOCIETE DE CAOUTCHOUC D
# 1                   ANTWERP              OUTSPAN IVOI R E
# 2                   ANTWERP         SOUTHLAND KATI COTE D
# 3                   ANTWERP         SOUTHLAND KATI COTE D
# 4                   ANTWERP       COMPAGNIE IVOIRIENN E D
# 5                        LE  COMPAGNIE DE TRANSFORMATIO N
# 6                   ANTWERP   ASIA AFRICA RUBBER INDUSTRY
# 7                 DUNKERQUE           BOLLORE TRANSPO R T
# 8                   ANTWERP                     SAI C S A
# 9                   ANTWERP  LA COMPAGNIE DES CAOUTCHOUCS
# 10                  ANTWERP         SOUTHLAND KATI COTE D
# 11                  ANTWERP  Compagnie des Caoutchoucs du
# 12                  TILBURY    SOCIETE AFRICAINE DE CACAO
# 13                  TILBURY        PLANTATION JEAN EGLI N
# 14                  ANTWERP                       S A I C
# 15                  ANTWERP                       S A I C
# 16                  ANTWERP  LA COMPAGNIE DES CAOUTCHOUCS
# 17                  ANTWERP  LA COMPAGNIE DES CAOUTCHOUCS
# 18                  ANTWERP  LA COMPAGNIE DES CAOUTCHOUCS
# 19                  ANTWERP  LA COMPAGNIE DES CAOUTCHOUCS
#
#                  Consigner                                  Notifie  \
# 0    TO ORDER QUANTITY 201       QINGDAO HUIXIN INTERNATIONAL TRADE
# 1          TO ORDER SPLI T           OLAM INTERNATIONAL LIMITED CTR
# 2      TO ORDER NET WEIGHT                 SOUTHLAND GLOBAL PTE LTD
# 3    TO ORDER GROSS WEIGHT                 SOUTHLAND GLOBAL PTE LTD
# 4            TO ORDER D6 E                 R1 INTERNATIONAL PTE LTD
# 5    TO ORDER GROSS WEIGHT                 R1 INTERNATIONAL PTE LTD
# 6         TO ORDER ORIGI N                       CHISAGE RESOUR C E
# 7     CARGILL BV POIDS NET                        CWT Commoditi e s
# 8         TO ORDER ORIGI N  QINGDAO SHANGCHENGJIA INTERNATIONAL NET
# 9    TO ORDER GROSS WEIGHT                 R1 INTERNATIONAL PTE LTD
# 10     TO ORDER NET WEIGHT                 SOUTHLAND GLOBAL PTE LTD
# 11      TO ORDER 576 BALES             QINGDAO YUANTAI SUPPLY CHAIN
# 12  BARRY CALLEBAUT MFG UK                   BARRY CALLEBAUT MFG UK
# 13          SIPEF NV TAR E           PORTICO SHIPPING LIMITED SPLIT
# 14     TO ORDER Commodit y       QINGDAO HUIXIN INTERNATIONAL TRADE
# 15      TO ORDER Quantit y       QINGDAO HUIXIN INTERNATIONAL TRADE
# 16   TO ORDER GROSS WEIGHT                 R1 INTERNATIONAL PTE LTD
# 17   TO ORDER GROSS WEIGHT                 R1 INTERNATIONAL PTE LTD
# 18   TO ORDER GROSS WEIGHT                 R1 INTERNATIONAL PTE LTD
# 19   TO ORDER GROSS WEIGHT                 R1 INTERNATIONAL PTE LTD
#
#                                           Description Type_contener  \
# 0   10 X 20'ST SAID TO CONTAIN 5760 SCA BP 281 ABO...             1
# 1   12X40'ST STC CNTR N/A 4 620 BAGS OF IVORY COAS...             2
# 2   26 BP 236 ABIDAJN 26 181 440 KGS NATURAL RUBBE...             1
# 3   10 X 20'DV STC 5760 BALES 26 BP 236 ABIDJAN 26...             1
# 4   10X20'ST SAID TO CONTAIN 5760 II PLATEAUX 7E T...             1
# 5   N/A DU CAOUTCHOUC IVOIRIEN 5760 BALES AV BOGA ...             1
# 6   10 X 20'ST SAID TO CONTAIN 28 BP 1465 ABIDJAN ...             1
# 7    N/A P/C CARGILL WEST AFRICA SA 1 LOT VRAC DE ...             1
# 8   10 X 20'ST STC N/A SOCIETE AGRO-INDUSTRIELLE 5...             1
# 9   10 X 20'ST STC N/A 18 BP 2897 5760 BALES OF NA...             1
# 10  26 BP 236 ABIDJAN 26 40 320 KGS NATURAL RUBBER...             1
# 11   Pakidie TSR10 / PAKRUB10 01 BP 1191 5760 BALE...             1
# 12   N/A 01 BP 1045 ABIDJAN 120 BIG CARTONE DE PAT...             1
# 13   CONTENIR 20700 CARTONS DE BANANES FRAICHES DE...             2
# 14  10 X 20'ST STC SOCIETE AGRO-INDUSTRIELLE DE 57...             1
# 15  10 X 20'ST STC N/A SOCIETE AGRO-INDUSTRIELLE D...             1
# 16  2 X 20'ST STC 18 BP 2897 ABIDJAN 18 1152 BALES...             1
# 17  18 BP 2897 1152 BALES OF NATURAL RUBBER ABIDJA...             1
# 18  4 X 20'ST STC 18 BP 2897 ABIDJAN 18 2304 BALES...             1
# 19  4 X 20'ST STC N/A 18 BP 2897 ABIDJAN 18 2304 B...             1
#
#    Nbre_colis Poids_march Unite_poids Nbre_contener Volum_march Unite_volum  \
# 0        5760  209.920000         TNE            10     210.000         MTQ
# 1        4620  303.396000         TNE            12     600.000         MTQ
# 2        5184  188.928000         TNE             9     189.000         MTQ
# 3        5760  209.920000         TNE            10     210.000         MTQ
# 4        5760  208.000000         TNE            10     250.000         MTQ
# 5        5760  208.000000         TNE            10     210.000         MTQ
# 6        5760  205.000000         TNE            10     250.000         MTQ
# 7          15  250.250000         TNE            15     375.000         MTQ
# 8        5760  204.800000         TNE            10     250.000         MTQ
# 9        5760  208.000000         TNE            10     250.000         MTQ
# 10       1152   41.984000         TNE             2      42.000         MTQ
# 11       5760  209.920000         TNE            10     210.000         MTQ
# 12        120  121.320000         TNE             5     100.000         MTQ
# 13      20700  418.760000         TNE            19     950.000         MTQ
# 14       5760  204.800000         TNE            10     250.000         MTQ
# 15       5760  204.800000         TNE            10     250.000         MTQ
# 16       1152   41.600000         TNE             2      50.000         MTQ
# 17       1152   41.600000         TNE             2      50.000         MTQ
# 18       2304   83.200000         TNE             4     100.000         MTQ
# 19       2304   83.200000         TNE             4     100.000         MTQ
#
#    Nom_du_Fichier
# 0         CMA.pdf
# 1         CMA.pdf
# 2         CMA.pdf
# 3         CMA.pdf
# 4         CMA.pdf
# 5         CMA.pdf
# 6         CMA.pdf
# 7         CMA.pdf
# 8         CMA.pdf
# 9         CMA.pdf
# 10        CMA.pdf
# 11        CMA.pdf
# 12        CMA.pdf
# 13        CMA.pdf
# 14        CMA.pdf
# 15        CMA.pdf
# 16        CMA.pdf
# 17        CMA.pdf
# 18        CMA.pdf
# 19        CMA.pdf

# %%
#pip install PyPDF2

# %%
# Out:
# []
